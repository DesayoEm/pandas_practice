# %%
import pandas as pd
import pyarrow.parquet as pq

# %%
pf = pq.ParquetFile("page1.parquet")

# %%
print(pf.schema)
# Out:
# <pyarrow._parquet.ParquetSchema object at 0x000001E37DCC6F40>
# required group field_id=-1 schema {
#   optional group field_id=-1 studies {
#     optional group field_id=-1 annotationSection {
#       optional group field_id=-1 annotationModule {
#         optional group field_id=-1 unpostedAnnotation {
#           optional group field_id=-1 unpostedEvents (List) {
#             repeated group field_id=-1 list {
#               optional group field_id=-1 element {
#                 optional binary field_id=-1 date (String);
#                 optional binary field_id=-1 type (String);
#               }
#             }
#           }
#           optional binary field_id=-1 unpostedResponsibleParty (String);
#         }
#       }
#     }
#     optional group field_id=-1 derivedSection {
#       optional group field_id=-1 conditionBrowseModule {
#         optional group field_id=-1 ancestors (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 id (String);
#               optional binary field_id=-1 term (String);
#             }
#           }
#         }
#         optional group field_id=-1 meshes (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 id (String);
#               optional binary field_id=-1 term (String);
#             }
#           }
#         }
#       }
#       optional group field_id=-1 interventionBrowseModule {
#         optional group field_id=-1 ancestors (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 id (String);
#               optional binary field_id=-1 term (String);
#             }
#           }
#         }
#         optional group field_id=-1 meshes (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 id (String);
#               optional binary field_id=-1 term (String);
#             }
#           }
#         }
#       }
#       optional group field_id=-1 miscInfoModule {
#         optional group field_id=-1 removedCountries (List) {
#           repeated group field_id=-1 list {
#             optional binary field_id=-1 element (String);
#           }
#         }
#         optional group field_id=-1 submissionTracking {
#           optional binary field_id=-1 estimatedResultsFirstSubmitDate (String);
#           optional group field_id=-1 firstMcpInfo {
#             optional group field_id=-1 postDateStruct {
#               optional binary field_id=-1 date (String);
#               optional binary field_id=-1 type (String);
#             }
#           }
#           optional group field_id=-1 submissionInfos (List) {
#             repeated group field_id=-1 list {
#               optional group field_id=-1 element {
#                 optional int64 field_id=-1 mcpReleaseN;
#                 optional binary field_id=-1 releaseDate (String);
#                 optional binary field_id=-1 resetDate (String);
#               }
#             }
#           }
#         }
#         optional binary field_id=-1 versionHolder (String);
#       }
#     }
#     optional group field_id=-1 documentSection {
#       optional group field_id=-1 largeDocumentModule {
#         optional group field_id=-1 largeDocs (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 date (String);
#               optional binary field_id=-1 filename (String);
#               optional boolean field_id=-1 hasIcf;
#               optional boolean field_id=-1 hasProtocol;
#               optional boolean field_id=-1 hasSap;
#               optional binary field_id=-1 label (String);
#               optional int64 field_id=-1 size;
#               optional binary field_id=-1 typeAbbrev (String);
#               optional binary field_id=-1 uploadDate (String);
#             }
#           }
#         }
#         optional boolean field_id=-1 noSap;
#       }
#     }
#     optional boolean field_id=-1 hasResults;
#     optional group field_id=-1 protocolSection {
#       optional group field_id=-1 armsInterventionsModule {
#         optional group field_id=-1 armGroups (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 description (String);
#               optional group field_id=-1 interventionNames (List) {
#                 repeated group field_id=-1 list {
#                   optional binary field_id=-1 element (String);
#                 }
#               }
#               optional binary field_id=-1 label (String);
#               optional binary field_id=-1 type (String);
#             }
#           }
#         }
#         optional group field_id=-1 interventions (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional group field_id=-1 armGroupLabels (List) {
#                 repeated group field_id=-1 list {
#                   optional binary field_id=-1 element (String);
#                 }
#               }
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 name (String);
#               optional group field_id=-1 otherNames (List) {
#                 repeated group field_id=-1 list {
#                   optional binary field_id=-1 element (String);
#                 }
#               }
#               optional binary field_id=-1 type (String);
#             }
#           }
#         }
#       }
#       optional group field_id=-1 conditionsModule {
#         optional group field_id=-1 conditions (List) {
#           repeated group field_id=-1 list {
#             optional binary field_id=-1 element (String);
#           }
#         }
#         optional group field_id=-1 keywords (List) {
#           repeated group field_id=-1 list {
#             optional binary field_id=-1 element (String);
#           }
#         }
#       }
#       optional group field_id=-1 contactsLocationsModule {
#         optional group field_id=-1 centralContacts (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 email (String);
#               optional binary field_id=-1 name (String);
#               optional binary field_id=-1 phone (String);
#               optional binary field_id=-1 phoneExt (String);
#               optional binary field_id=-1 role (String);
#             }
#           }
#         }
#         optional group field_id=-1 locations (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 city (String);
#               optional group field_id=-1 contacts (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional binary field_id=-1 email (String);
#                     optional binary field_id=-1 name (String);
#                     optional binary field_id=-1 phone (String);
#                     optional binary field_id=-1 phoneExt (String);
#                     optional binary field_id=-1 role (String);
#                   }
#                 }
#               }
#               optional binary field_id=-1 country (String);
#               optional binary field_id=-1 facility (String);
#               optional group field_id=-1 geoPoint {
#                 optional double field_id=-1 lat;
#                 optional double field_id=-1 lon;
#               }
#               optional binary field_id=-1 state (String);
#               optional binary field_id=-1 status (String);
#               optional binary field_id=-1 zip (String);
#             }
#           }
#         }
#         optional group field_id=-1 overallOfficials (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 affiliation (String);
#               optional binary field_id=-1 name (String);
#               optional binary field_id=-1 role (String);
#             }
#           }
#         }
#       }
#       optional group field_id=-1 descriptionModule {
#         optional binary field_id=-1 briefSummary (String);
#         optional binary field_id=-1 detailedDescription (String);
#       }
#       optional group field_id=-1 designModule {
#         optional group field_id=-1 bioSpec {
#           optional binary field_id=-1 description (String);
#           optional binary field_id=-1 retention (String);
#         }
#         optional group field_id=-1 designInfo {
#           optional binary field_id=-1 allocation (String);
#           optional binary field_id=-1 interventionModel (String);
#           optional binary field_id=-1 interventionModelDescription (String);
#           optional group field_id=-1 maskingInfo {
#             optional binary field_id=-1 masking (String);
#             optional binary field_id=-1 maskingDescription (String);
#             optional group field_id=-1 whoMasked (List) {
#               repeated group field_id=-1 list {
#                 optional binary field_id=-1 element (String);
#               }
#             }
#           }
#           optional binary field_id=-1 observationalModel (String);
#           optional binary field_id=-1 primaryPurpose (String);
#           optional binary field_id=-1 timePerspective (String);
#         }
#         optional group field_id=-1 enrollmentInfo {
#           optional int64 field_id=-1 count;
#           optional binary field_id=-1 type (String);
#         }
#         optional group field_id=-1 expandedAccessTypes {
#           optional boolean field_id=-1 intermediate;
#           optional boolean field_id=-1 treatment;
#         }
#         optional boolean field_id=-1 patientRegistry;
#         optional group field_id=-1 phases (List) {
#           repeated group field_id=-1 list {
#             optional binary field_id=-1 element (String);
#           }
#         }
#         optional binary field_id=-1 studyType (String);
#         optional binary field_id=-1 targetDuration (String);
#       }
#       optional group field_id=-1 eligibilityModule {
#         optional binary field_id=-1 eligibilityCriteria (String);
#         optional boolean field_id=-1 genderBased;
#         optional binary field_id=-1 genderDescription (String);
#         optional boolean field_id=-1 healthyVolunteers;
#         optional binary field_id=-1 maximumAge (String);
#         optional binary field_id=-1 minimumAge (String);
#         optional binary field_id=-1 samplingMethod (String);
#         optional binary field_id=-1 sex (String);
#         optional group field_id=-1 stdAges (List) {
#           repeated group field_id=-1 list {
#             optional binary field_id=-1 element (String);
#           }
#         }
#         optional binary field_id=-1 studyPopulation (String);
#       }
#       optional group field_id=-1 identificationModule {
#         optional binary field_id=-1 acronym (String);
#         optional binary field_id=-1 briefTitle (String);
#         optional binary field_id=-1 nctId (String);
#         optional group field_id=-1 nctIdAliases (List) {
#           repeated group field_id=-1 list {
#             optional binary field_id=-1 element (String);
#           }
#         }
#         optional binary field_id=-1 officialTitle (String);
#         optional group field_id=-1 orgStudyIdInfo {
#           optional binary field_id=-1 id (String);
#           optional binary field_id=-1 link (String);
#           optional binary field_id=-1 type (String);
#         }
#         optional group field_id=-1 organization {
#           optional binary field_id=-1 class (String);
#           optional binary field_id=-1 fullName (String);
#         }
#         optional group field_id=-1 secondaryIdInfos (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 domain (String);
#               optional binary field_id=-1 id (String);
#               optional binary field_id=-1 link (String);
#               optional binary field_id=-1 type (String);
#             }
#           }
#         }
#       }
#       optional group field_id=-1 ipdSharingStatementModule {
#         optional binary field_id=-1 accessCriteria (String);
#         optional binary field_id=-1 description (String);
#         optional group field_id=-1 infoTypes (List) {
#           repeated group field_id=-1 list {
#             optional binary field_id=-1 element (String);
#           }
#         }
#         optional binary field_id=-1 ipdSharing (String);
#         optional binary field_id=-1 timeFrame (String);
#         optional binary field_id=-1 url (String);
#       }
#       optional group field_id=-1 outcomesModule {
#         optional group field_id=-1 otherOutcomes (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 measure (String);
#               optional binary field_id=-1 timeFrame (String);
#             }
#           }
#         }
#         optional group field_id=-1 primaryOutcomes (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 measure (String);
#               optional binary field_id=-1 timeFrame (String);
#             }
#           }
#         }
#         optional group field_id=-1 secondaryOutcomes (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 measure (String);
#               optional binary field_id=-1 timeFrame (String);
#             }
#           }
#         }
#       }
#       optional group field_id=-1 oversightModule {
#         optional boolean field_id=-1 isFdaRegulatedDevice;
#         optional boolean field_id=-1 isFdaRegulatedDrug;
#         optional boolean field_id=-1 isUnapprovedDevice;
#         optional boolean field_id=-1 isUsExport;
#         optional boolean field_id=-1 oversightHasDmc;
#       }
#       optional group field_id=-1 referencesModule {
#         optional group field_id=-1 availIpds (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 comment (String);
#               optional binary field_id=-1 id (String);
#               optional binary field_id=-1 type (String);
#               optional binary field_id=-1 url (String);
#             }
#           }
#         }
#         optional group field_id=-1 references (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 citation (String);
#               optional binary field_id=-1 pmid (String);
#               optional binary field_id=-1 type (String);
#             }
#           }
#         }
#         optional group field_id=-1 seeAlsoLinks (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 label (String);
#               optional binary field_id=-1 url (String);
#             }
#           }
#         }
#       }
#       optional group field_id=-1 sponsorCollaboratorsModule {
#         optional group field_id=-1 collaborators (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 class (String);
#               optional binary field_id=-1 name (String);
#             }
#           }
#         }
#         optional group field_id=-1 leadSponsor {
#           optional binary field_id=-1 class (String);
#           optional binary field_id=-1 name (String);
#         }
#         optional group field_id=-1 responsibleParty {
#           optional binary field_id=-1 investigatorAffiliation (String);
#           optional binary field_id=-1 investigatorFullName (String);
#           optional binary field_id=-1 investigatorTitle (String);
#           optional binary field_id=-1 oldNameTitle (String);
#           optional binary field_id=-1 oldOrganization (String);
#           optional binary field_id=-1 type (String);
#         }
#       }
#       optional group field_id=-1 statusModule {
#         optional group field_id=-1 completionDateStruct {
#           optional binary field_id=-1 date (String);
#           optional binary field_id=-1 type (String);
#         }
#         optional boolean field_id=-1 delayedPosting;
#         optional group field_id=-1 dispFirstPostDateStruct {
#           optional binary field_id=-1 date (String);
#           optional binary field_id=-1 type (String);
#         }
#         optional binary field_id=-1 dispFirstSubmitDate (String);
#         optional binary field_id=-1 dispFirstSubmitQcDate (String);
#         optional group field_id=-1 expandedAccessInfo {
#           optional boolean field_id=-1 hasExpandedAccess;
#         }
#         optional binary field_id=-1 lastKnownStatus (String);
#         optional group field_id=-1 lastUpdatePostDateStruct {
#           optional binary field_id=-1 date (String);
#           optional binary field_id=-1 type (String);
#         }
#         optional binary field_id=-1 lastUpdateSubmitDate (String);
#         optional binary field_id=-1 overallStatus (String);
#         optional group field_id=-1 primaryCompletionDateStruct {
#           optional binary field_id=-1 date (String);
#           optional binary field_id=-1 type (String);
#         }
#         optional group field_id=-1 resultsFirstPostDateStruct {
#           optional binary field_id=-1 date (String);
#           optional binary field_id=-1 type (String);
#         }
#         optional binary field_id=-1 resultsFirstSubmitDate (String);
#         optional binary field_id=-1 resultsFirstSubmitQcDate (String);
#         optional group field_id=-1 startDateStruct {
#           optional binary field_id=-1 date (String);
#           optional binary field_id=-1 type (String);
#         }
#         optional binary field_id=-1 statusVerifiedDate (String);
#         optional group field_id=-1 studyFirstPostDateStruct {
#           optional binary field_id=-1 date (String);
#           optional binary field_id=-1 type (String);
#         }
#         optional binary field_id=-1 studyFirstSubmitDate (String);
#         optional binary field_id=-1 studyFirstSubmitQcDate (String);
#         optional binary field_id=-1 whyStopped (String);
#       }
#     }
#     optional group field_id=-1 resultsSection {
#       optional group field_id=-1 adverseEventsModule {
#         optional binary field_id=-1 description (String);
#         optional group field_id=-1 eventGroups (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional int64 field_id=-1 deathsNumAffected;
#               optional int64 field_id=-1 deathsNumAtRisk;
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 id (String);
#               optional int64 field_id=-1 otherNumAffected;
#               optional int64 field_id=-1 otherNumAtRisk;
#               optional int64 field_id=-1 seriousNumAffected;
#               optional int64 field_id=-1 seriousNumAtRisk;
#               optional binary field_id=-1 title (String);
#             }
#           }
#         }
#         optional binary field_id=-1 frequencyThreshold (String);
#         optional group field_id=-1 otherEvents (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 assessmentType (String);
#               optional binary field_id=-1 notes (String);
#               optional binary field_id=-1 organSystem (String);
#               optional binary field_id=-1 sourceVocabulary (String);
#               optional group field_id=-1 stats (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional binary field_id=-1 groupId (String);
#                     optional int64 field_id=-1 numAffected;
#                     optional int64 field_id=-1 numAtRisk;
#                     optional int64 field_id=-1 numEvents;
#                   }
#                 }
#               }
#               optional binary field_id=-1 term (String);
#             }
#           }
#         }
#         optional group field_id=-1 seriousEvents (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 assessmentType (String);
#               optional binary field_id=-1 notes (String);
#               optional binary field_id=-1 organSystem (String);
#               optional binary field_id=-1 sourceVocabulary (String);
#               optional group field_id=-1 stats (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional binary field_id=-1 groupId (String);
#                     optional int64 field_id=-1 numAffected;
#                     optional int64 field_id=-1 numAtRisk;
#                     optional int64 field_id=-1 numEvents;
#                   }
#                 }
#               }
#               optional binary field_id=-1 term (String);
#             }
#           }
#         }
#         optional binary field_id=-1 timeFrame (String);
#       }
#       optional group field_id=-1 baselineCharacteristicsModule {
#         optional group field_id=-1 denoms (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional group field_id=-1 counts (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional binary field_id=-1 groupId (String);
#                     optional binary field_id=-1 value (String);
#                   }
#                 }
#               }
#               optional binary field_id=-1 units (String);
#             }
#           }
#         }
#         optional group field_id=-1 groups (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 id (String);
#               optional binary field_id=-1 title (String);
#             }
#           }
#         }
#         optional group field_id=-1 measures (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional boolean field_id=-1 calculatePct;
#               optional group field_id=-1 classes (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional group field_id=-1 categories (List) {
#                       repeated group field_id=-1 list {
#                         optional group field_id=-1 element {
#                           optional group field_id=-1 measurements (List) {
#                             repeated group field_id=-1 list {
#                               optional group field_id=-1 element {
#                                 optional binary field_id=-1 comment (String);
#                                 optional binary field_id=-1 groupId (String);
#                                 optional binary field_id=-1 lowerLimit (String);
#                                 optional binary field_id=-1 spread (String);
#                                 optional binary field_id=-1 upperLimit (String);
#                                 optional binary field_id=-1 value (String);
#                               }
#                             }
#                           }
#                           optional binary field_id=-1 title (String);
#                         }
#                       }
#                     }
#                     optional group field_id=-1 denoms (List) {
#                       repeated group field_id=-1 list {
#                         optional group field_id=-1 element {
#                           optional group field_id=-1 counts (List) {
#                             repeated group field_id=-1 list {
#                               optional group field_id=-1 element {
#                                 optional binary field_id=-1 groupId (String);
#                                 optional binary field_id=-1 value (String);
#                               }
#                             }
#                           }
#                           optional binary field_id=-1 units (String);
#                         }
#                       }
#                     }
#                     optional binary field_id=-1 title (String);
#                   }
#                 }
#               }
#               optional binary field_id=-1 denomUnitsSelected (String);
#               optional group field_id=-1 denoms (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional group field_id=-1 counts (List) {
#                       repeated group field_id=-1 list {
#                         optional group field_id=-1 element {
#                           optional binary field_id=-1 groupId (String);
#                           optional binary field_id=-1 value (String);
#                         }
#                       }
#                     }
#                     optional binary field_id=-1 units (String);
#                   }
#                 }
#               }
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 dispersionType (String);
#               optional binary field_id=-1 paramType (String);
#               optional binary field_id=-1 populationDescription (String);
#               optional binary field_id=-1 title (String);
#               optional binary field_id=-1 unitOfMeasure (String);
#             }
#           }
#         }
#         optional binary field_id=-1 populationDescription (String);
#         optional binary field_id=-1 typeUnitsAnalyzed (String);
#       }
#       optional group field_id=-1 moreInfoModule {
#         optional group field_id=-1 certainAgreement {
#           optional binary field_id=-1 otherDetails (String);
#           optional boolean field_id=-1 piSponsorEmployee;
#           optional binary field_id=-1 restrictionType (String);
#           optional boolean field_id=-1 restrictiveAgreement;
#         }
#         optional group field_id=-1 limitationsAndCaveats {
#           optional binary field_id=-1 description (String);
#         }
#         optional group field_id=-1 pointOfContact {
#           optional binary field_id=-1 email (String);
#           optional binary field_id=-1 organization (String);
#           optional binary field_id=-1 phone (String);
#           optional binary field_id=-1 phoneExt (String);
#           optional binary field_id=-1 title (String);
#         }
#       }
#       optional group field_id=-1 outcomeMeasuresModule {
#         optional group field_id=-1 outcomeMeasures (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional group field_id=-1 analyses (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional binary field_id=-1 ciLowerLimit (String);
#                     optional binary field_id=-1 ciNumSides (String);
#                     optional binary field_id=-1 ciPctValue (String);
#                     optional binary field_id=-1 ciUpperLimit (String);
#                     optional binary field_id=-1 dispersionType (String);
#                     optional binary field_id=-1 dispersionValue (String);
#                     optional binary field_id=-1 estimateComment (String);
#                     optional binary field_id=-1 groupDescription (String);
#                     optional group field_id=-1 groupIds (List) {
#                       repeated group field_id=-1 list {
#                         optional binary field_id=-1 element (String);
#                       }
#                     }
#                     optional binary field_id=-1 nonInferiorityComment (String);
#                     optional binary field_id=-1 nonInferiorityType (String);
#                     optional binary field_id=-1 otherAnalysisDescription (String);
#                     optional binary field_id=-1 pValue (String);
#                     optional binary field_id=-1 pValueComment (String);
#                     optional binary field_id=-1 paramType (String);
#                     optional binary field_id=-1 paramValue (String);
#                     optional binary field_id=-1 statisticalComment (String);
#                     optional binary field_id=-1 statisticalMethod (String);
#                     optional boolean field_id=-1 testedNonInferiority;
#                   }
#                 }
#               }
#               optional binary field_id=-1 anticipatedPostingDate (String);
#               optional boolean field_id=-1 calculatePct;
#               optional group field_id=-1 classes (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional group field_id=-1 categories (List) {
#                       repeated group field_id=-1 list {
#                         optional group field_id=-1 element {
#                           optional group field_id=-1 measurements (List) {
#                             repeated group field_id=-1 list {
#                               optional group field_id=-1 element {
#                                 optional binary field_id=-1 comment (String);
#                                 optional binary field_id=-1 groupId (String);
#                                 optional binary field_id=-1 lowerLimit (String);
#                                 optional binary field_id=-1 spread (String);
#                                 optional binary field_id=-1 upperLimit (String);
#                                 optional binary field_id=-1 value (String);
#                               }
#                             }
#                           }
#                           optional binary field_id=-1 title (String);
#                         }
#                       }
#                     }
#                     optional group field_id=-1 denoms (List) {
#                       repeated group field_id=-1 list {
#                         optional group field_id=-1 element {
#                           optional group field_id=-1 counts (List) {
#                             repeated group field_id=-1 list {
#                               optional group field_id=-1 element {
#                                 optional binary field_id=-1 groupId (String);
#                                 optional binary field_id=-1 value (String);
#                               }
#                             }
#                           }
#                           optional binary field_id=-1 units (String);
#                         }
#                       }
#                     }
#                     optional binary field_id=-1 title (String);
#                   }
#                 }
#               }
#               optional binary field_id=-1 denomUnitsSelected (String);
#               optional group field_id=-1 denoms (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional group field_id=-1 counts (List) {
#                       repeated group field_id=-1 list {
#                         optional group field_id=-1 element {
#                           optional binary field_id=-1 groupId (String);
#                           optional binary field_id=-1 value (String);
#                         }
#                       }
#                     }
#                     optional binary field_id=-1 units (String);
#                   }
#                 }
#               }
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 dispersionType (String);
#               optional group field_id=-1 groups (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional binary field_id=-1 description (String);
#                     optional binary field_id=-1 id (String);
#                     optional binary field_id=-1 title (String);
#                   }
#                 }
#               }
#               optional binary field_id=-1 paramType (String);
#               optional binary field_id=-1 populationDescription (String);
#               optional binary field_id=-1 reportingStatus (String);
#               optional binary field_id=-1 timeFrame (String);
#               optional binary field_id=-1 title (String);
#               optional binary field_id=-1 type (String);
#               optional binary field_id=-1 typeUnitsAnalyzed (String);
#               optional binary field_id=-1 unitOfMeasure (String);
#             }
#           }
#         }
#       }
#       optional group field_id=-1 participantFlowModule {
#         optional group field_id=-1 groups (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 id (String);
#               optional binary field_id=-1 title (String);
#             }
#           }
#         }
#         optional group field_id=-1 periods (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional group field_id=-1 dropWithdraws (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional group field_id=-1 reasons (List) {
#                       repeated group field_id=-1 list {
#                         optional group field_id=-1 element {
#                           optional binary field_id=-1 groupId (String);
#                           optional binary field_id=-1 numSubjects (String);
#                         }
#                       }
#                     }
#                     optional binary field_id=-1 type (String);
#                   }
#                 }
#               }
#               optional group field_id=-1 milestones (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional group field_id=-1 achievements (List) {
#                       repeated group field_id=-1 list {
#                         optional group field_id=-1 element {
#                           optional binary field_id=-1 comment (String);
#                           optional binary field_id=-1 groupId (String);
#                           optional binary field_id=-1 numSubjects (String);
#                           optional binary field_id=-1 numUnits (String);
#                         }
#                       }
#                     }
#                     optional binary field_id=-1 comment (String);
#                     optional binary field_id=-1 type (String);
#                   }
#                 }
#               }
#               optional binary field_id=-1 title (String);
#             }
#           }
#         }
#         optional binary field_id=-1 preAssignmentDetails (String);
#         optional binary field_id=-1 recruitmentDetails (String);
#         optional binary field_id=-1 typeUnitsAnalyzed (String);
#       }
#     }
#   }
#   optional binary field_id=-1 nextPageToken (String);
# }

# %%
df_studies = pd.read_parquet("page1.parquet")

# %%
all_protocol_data = df_studies['studies'].apply(lambda x: x.get('protocolSection'))

# %%
intervention_df = [protocol_data['armsInterventionsModule'] for protocol_data in all_protocol_data]

# %%
print(intervention_df[0])
# Out:
# {'armGroups': array([{'description': "Participants in this group will receive an intervention based on the salutogenic model, aimed at enhancing the sense of coherence and promoting healthy aging. The program will focus on improving participants' overall quality of life by strengthening their internal resources and fostering resilience. The intervention will include educational sessions, guided discussions, and practical strategies for maintaining physical and mental health in older adults with hypertension and diabetes. The intervention will be delivered over a specified period, with regular follow-ups to assess progress.", 'interventionNames': array(['Behavioral: Salutogenic Model-Based Healthy Aging Program'],
#              dtype=object), 'label': 'Intervention Group', 'type': 'EXPERIMENTAL'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ,
#        {'description': 'Participants in this group will receive standard care as provided by the nursing homes, without any additional intervention based on the salutogenic model. They will continue to receive routine support and healthcare services that are typically available to older adults in the facility, including management of hypertension and diabetes. This group will be monitored for any changes in quality of life and sense of coherence over the course of the study, but no specific program or educational sessions will be provided.', 'interventionNames': None, 'label': 'control group', 'type': 'NO_INTERVENTION'}],
#       dtype=object), 'interventions': array([{'armGroupLabels': array(['Intervention Group'], dtype=object), 'description': "The Salutogenic Model-Based Healthy Aging Program is designed to enhance the sense of coherence and promote healthy aging among older adults aged 60-70. The program focuses on strengthening participants' internal resources, building resilience, and improving overall quality of life. It includes educational sessions, group discussions, and practical strategies for managing hypertension and diabetes, all while emphasizing physical, emotional, and mental well-being. The program aims to empower participants to make informed lifestyle choices and cope with the challenges of aging. Participants will receive regular follow-up assessments to track progress and ensure continued support throughout the study period.", 'name': 'Salutogenic Model-Based Healthy Aging Program', 'otherNames': array(['educational intervention'], dtype=object), 'type': 'BEHAVIORAL'}],
#       dtype=object)}

# %%
df_normalized = pd.json_normalize(df_studies['studies'])

# %%
# print(df_normalized)

# %%
nct_series = df_normalized['protocolSection.identificationModule.nctId']

# %%
study_df = pd.DataFrame({
    #identification
    'nct_id': df_normalized['protocolSection.identificationModule.nctId'],
    'title': df_normalized['protocolSection.identificationModule.officialTitle'],
    'acronym': df_normalized['protocolSection.identificationModule.acronym'],
    'organization_name': df_normalized['protocolSection.identificationModule.organization.fullName'],
    'organization_type': df_normalized['protocolSection.identificationModule.organization.class'],

    #sponsors and collaborators
    'sponsor_name': df_normalized['protocolSection.sponsorCollaboratorsModule.leadSponsor.name'],
    'sponsor_type': df_normalized['protocolSection.sponsorCollaboratorsModule.leadSponsor.class'],

    #description
    'brief_summary': df_normalized['protocolSection.descriptionModule.briefSummary'],
    'detailed_description': df_normalized['protocolSection.descriptionModule.detailedDescription'],

    #conditions
    'condition': df_normalized['protocolSection.conditionsModule.conditions'],
    'keyword': df_normalized['protocolSection.conditionsModule.keywords'],

    #design
    'study_type': df_normalized['protocolSection.designModule.studyType'],
    'patient_registry': df_normalized['protocolSection.designModule.patientRegistry'],
    'target_duration': df_normalized['protocolSection.designModule.targetDuration'],
    'study_phase': df_normalized['protocolSection.designModule.targetDuration'],

    'design_allocation': df_normalized['protocolSection.designModule.designInfo.allocation'],
    'design_intervention_model': df_normalized['protocolSection.designModule.designInfo.interventionModel'],
    'design_intervention_model_desc': df_normalized['protocolSection.designModule.designInfo.interventionModelDescription'],

    'design_primary_purpose': df_normalized['protocolSection.designModule.designInfo.primaryPurpose'],
    'design_observational_model': df_normalized['protocolSection.designModule.designInfo.observationalModel'],
    'design_time_perspective': df_normalized['protocolSection.designModule.designInfo.timePerspective'],
    'design_masking': df_normalized['protocolSection.designModule.designInfo.maskingInfo.masking'],
    'design_masking_decsription': df_normalized['protocolSection.designModule.designInfo.maskingInfo.maskingDescription'],
    'design_who_masked': df_normalized['protocolSection.designModule.designInfo.maskingInfo.whoMasked'],

     #expanded access
    'exp_acc_type_intermediate': df_normalized['protocolSection.designModule.expandedAccessTypes.intermediate'],
    'exp_acc_type_treatment': df_normalized['protocolSection.designModule.expandedAccessTypes.treatment'],

    #Biospec
    'biospec_retention': df_normalized['protocolSection.designModule.bioSpec.retention'],
    'biospec_description': df_normalized['protocolSection.designModule.bioSpec.description'],

    #enrollment
    'enrollment_type': df_normalized['protocolSection.designModule.enrollmentInfo.type'],
    'enrollment_count': df_normalized['protocolSection.designModule.enrollmentInfo.count'],

    #arm group
    'arm_group_label': df_normalized['protocolSection.designModule.enrollmentInfo.type'],
    'arm_group_type': df_normalized['protocolSection.designModule.enrollmentInfo.count'],

     #eligibility
    'eligibility_criteria': df_normalized['protocolSection.eligibilityModule.eligibilityCriteria'],
    'healthy_volunteers': df_normalized['protocolSection.eligibilityModule.healthyVolunteers'],

    'sex': df_normalized['protocolSection.eligibilityModule.sex'],
    'gender_based': df_normalized['protocolSection.eligibilityModule.genderBased'],
    'gender_description': df_normalized['protocolSection.eligibilityModule.genderDescription'],
    'min_age': df_normalized['protocolSection.eligibilityModule.genderBased'],
    'max_age': df_normalized['protocolSection.eligibilityModule.sex'],
    'population_description': df_normalized['protocolSection.eligibilityModule.studyPopulation'],
    'sampling_method': df_normalized['protocolSection.eligibilityModule.samplingMethod'],

     #status
    'overall_status': df_normalized['protocolSection.statusModule.lastKnownStatus'],
    'last_known_status': df_normalized['protocolSection.statusModule.lastKnownStatus'],
    
    'start_date': df_normalized['protocolSection.statusModule.startDateStruct.date'],
    'start_date_type': df_normalized['protocolSection.statusModule.startDateStruct.type'],
    
    'first_submit_date': df_normalized['protocolSection.statusModule.studyFirstSubmitDate'],
    'first_submit_qc_date': df_normalized['protocolSection.statusModule.studyFirstSubmitQcDate'],
    
    'last_update_submit': df_normalized['protocolSection.statusModule.lastUpdateSubmitDate'],
    'completion_date': df_normalized['protocolSection.statusModule.completionDateStruct.date'],
    'completion_date_type': df_normalized['protocolSection.statusModule.completionDateStruct.type'],
    
    'why_stopped': df_normalized['protocolSection.statusModule.whyStopped'],
    'has_exp_access': df_normalized['protocolSection.statusModule.expandedAccessInfo.hasExpandedAccess'],

     #oversight
    'has_dmc': df_normalized['protocolSection.oversightModule.oversightHasDmc'],
    'is_fda_regulated_drug': df_normalized['protocolSection.oversightModule.isFdaRegulatedDrug'],
    'is_fda_regulated_device': df_normalized['protocolSection.oversightModule.isFdaRegulatedDevice'],
    'is_unapproved_device': df_normalized['protocolSection.oversightModule.isUnapprovedDevice'],

    # individual participant data
    'ipd_sharing': df_normalized['protocolSection.ipdSharingStatementModule.ipdSharing'],
    'ipd_sharing_description': df_normalized['protocolSection.ipdSharingStatementModule.description'],
    'ipd_sharing_info_type': df_normalized['protocolSection.ipdSharingStatementModule.infoTypes'],
    'ipd_sharing_time_frame': df_normalized['protocolSection.ipdSharingStatementModule.timeFrame'],
    'ipd_sharing_access_criteria': df_normalized['protocolSection.ipdSharingStatementModule.accessCriteria'],
    'ipd_sharing_url': df_normalized['protocolSection.ipdSharingStatementModule.url'],

    # results
    'ipd_sharing': df_normalized['protocolSection.ipdSharingStatementModule.ipdSharing'],
    'ipd_sharing_description': df_normalized['protocolSection.ipdSharingStatementModule.description'],
    'ipd_sharing_info_type': df_normalized['protocolSection.ipdSharingStatementModule.infoTypes'],
    'ipd_sharing_time_frame': df_normalized['protocolSection.ipdSharingStatementModule.timeFrame'],


    # participant_flow
    'flow_pre_assignment_details': df_normalized['resultsSection.participantFlowModule.preAssignmentDetails'],
    'flow_recruitment_details': df_normalized['resultsSection.participantFlowModule.recruitmentDetails'],
    'flow_type_unit_analysed': df_normalized['resultsSection.participantFlowModule.typeUnitsAnalyzed'],

     # baseline characteristics
    'bsln_pop_desc': df_normalized['resultsSection.baselineCharacteristicsModule.populationDescription'],
    'bsln_pop_units_analysed': df_normalized['resultsSection.baselineCharacteristicsModule.typeUnitsAnalyzed'],
    
    #sponsors and collaborators
    # 'collaborator_name': df_normalized['protocolSection.sponsorCollaboratorsModule.collaborators.name'],
    # 'collaborator_type': df_normalized['protocolSection.sponsorCollaboratorsModule.collaborators.class'],
    
    #expanded access
    # 'exp_acc_type_individual': df_normalized['protocolSection.designModule.expandedAccessTypes.individual'],

    #arm group
    # 'arm_group_description': df_normalized['protocolSection.armsInterventionsModule.armGroups.description'],
    # 'arm_group_intervention_names': df_normalized['protocolSection.armsInterventionsModule.armGroups.interventionNames'],

    #intervention
    # 'intervention_type': df_normalized['protocolSection.armsInterventionsModule.interventions.type'],
    # 'intervention_name': df_normalized['protocolSection.armsInterventionsModule.interventions.name'],
    # 'intervention_description': df_normalized['protocolSection.armsInterventionsModule.interventions.description'],
    # 'intervention_arm_group_labels': df_normalized['protocolSection.armsInterventionsModule.interventions.armGroupLabels'],
    # 'intervention_other_names': df_normalized['protocolSection.armsInterventionsModule.interventions.otherNames'],
    
    #outcomes
    # 'primary_outcome_measure': df_normalized['protocolSection.outcomesModule.primaryOutcomes.measure'],
    # 'primary_outcome_description': df_normalized['protocolSection.outcomesModule.primaryOutcomes.description'],
    # 'primary_outcome_time_frame': df_normalized['protocolSection.outcomesModule.primaryOutcomes.timeFrame'],

    # 'secondary_outcome_measure': df_normalized['protocolSection.outcomesModule.secondaryOutcomes.measure'],
    # 'secondary_outcome_description': df_normalized['protocolSection.outcomesModule.secondaryOutcomes.description'],
    # 'secondary_outcome_time_frame': df_normalized['protocolSection.outcomesModule.secondaryOutcomes.timeFrame'],

    # 'other_outcome_measure': df_normalized['protocolSection.outcomesModule.otherOutcomes.measure'],
    # 'other_outcome_description': df_normalized['protocolSection.outcomesModule.otherOutcomes.description'],
    # 'other_outcome_time_frame': df_normalized['protocolSection.outcomesModule.otherOutcomes.timeFrame'],

    #central contact
    # 'central_contact_name': df_normalized['protocolSection.contactsLocationsModule.centralContacts.name'],
    # 'central_contact_role': df_normalized['protocolSection.contactsLocationsModule.centralContacts.role'],
    # 'central_contact_phone': df_normalized['protocolSection.contactsLocationsModule.centralContacts.phone'],
    # 'central_contact_phone_ext': df_normalized['protocolSection.contactsLocationsModule.centralContacts.phoneExt'],
    # 'central_contact_email': df_normalized['protocolSection.contactsLocationsModule.centralContacts.email'],

     #study officials
    # 'official_name': df_normalized['protocolSection.contactsLocationsModule.overallOfficials.name'],
    # 'official_role': df_normalized['protocolSection.contactsLocationsModule.overallOfficials.role'],
    # 'official_affiliation': df_normalized['protocolSection.contactsLocationsModule.overallOfficials.affiliation'],

    #location
    # 'facility_name': df_normalized['protocolSection.contactsLocationsModule.locations.facility'],
    # 'facility_recruitment_status': df_normalized['protocolSection.contactsLocationsModule.locations.status'],
    # 'facility_city': df_normalized['protocolSection.contactsLocationsModule.locations.city'],
    # 'facility_state': df_normalized['protocolSection.contactsLocationsModule.locations.state'],
    # 'facility_zip': df_normalized['protocolSection.contactsLocationsModule.locations.zip'],
    # 'facility_country': df_normalized['protocolSection.contactsLocationsModule.locations.country'],


    #location contacts
    # 'facility_contact_name': df_normalized['protocolSection.contactsLocationsModule.locations.contacts.name'],
    # 'facility_contact_role': df_normalized['protocolSection.contactsLocationsModule.locations.contacts.role'],
    # 'facility_contact_phone': df_normalized['protocolSection.contactsLocationsModule.locations.contacts.phone'],
    # 'facility_contact_phone_ext': df_normalized['protocolSection.contactsLocationsModule.locations.contacts.phoneExt'],
    # 'facility_contact_email': df_normalized['protocolSection.contactsLocationsModule.locations.contacts.email'],


    #reference
    # 'ref_pmid': df_normalized['protocolSection.referencesModule.references.pmid'],
    # 'ref_type': df_normalized['protocolSection.referencesModule.references.type'],
    # 'ref_citation': df_normalized['protocolSection.referencesModule.references.citation'],

    #retraction
    # 'ret_pmid': df_normalized['protocolSection.referencesModule.references.retractions.pmid'],
    # 'ret_source': df_normalized['protocolSection.referencesModule.references.retractions.status'],

    #see also link
    # 'see_also_label': df_normalized['protocolSection.referencesModule.seeAlsoLinks.label'],
    # 'see_also_url': df_normalized['protocolSection.referencesModule.seeAlsoLinks.url'],
    
    #status
    # 'exp_access_id': df_normalized['protocolSection.statusModule.expandedAccessInfo.nctId'],

    #oversight
    # 'is_ppsd': df_normalized['protocolSection.oversightModule.isPpsd'],

    # participant_flow
    # 'flow_groups': df_normalized['resultsSection.participantFlowModule.groups'],
          # 'flow_group_id': df_normalized['resultsSection.participantFlowModule.groups.id'],
          # 'flow_group_title': df_normalized['resultsSection.participantFlowModule.groups.title'],
          # 'flow_group_description': df_normalized['resultsSection.participantFlowModule.groups.description'],

    # 'flow_period': df_normalized['resultsSection.participantFlowModule.periods'],
          # 'flow_period_title': df_normalized['resultsSection.participantFlowModule.periods.title'],
          # 'flow_period_milestone': df_normalized['resultsSection.participantFlowModule.periods.milestones'],
              # 'flow_milestone_type': df_normalized['resultsSection.participantFlowModule.periods.milestones.type'],
              # 'flow_milestone_comment': df_normalized['	resultsSection.participantFlowModule.periods.milestones.comment'],
    
          # 'flow_milestone_achievments': df_normalized['	resultsSection.participantFlowModule.periods.milestones.achievements'],
                # 'flow_achievment_grp_id': df_normalized['	resultsSection.participantFlowModule.periods.milestones.achievements.groupId'],
                # 'flow_achievment_grp_comment': df_normalized['resultsSection.participantFlowModule.periods.milestones.achievements.comment'],
                # 'flow_achievment_grp_num_participants': df_normalized['resultsSection.participantFlowModule.periods.milestones.achievements.numSubjects'],
                # 'flow_achievment_grp_num_units': df_normalized['resultsSection.participantFlowModule.periods.milestones.achievements.numUnits'],
    
         # 'flow_drop_withdraws': df_normalized['resultsSection.participantFlowModule.periods.dropWithdraws'],
               # 'flow_drop_withdraw_type': df_normalized['resultsSection.participantFlowModule.periods.dropWithdraws.type'],
               # 'flow_drop_wdraw_comment': df_normalized['resultsSection.participantFlowModule.periods.dropWithdraws.comment'],

               # 'flow_drop_wdraw_reason': df_normalized['resultsSection.participantFlowModule.periods.dropWithdraws.reasons'],
                    # 'flow_drop_wdraw_reason_grp_id': df_normalized['resultsSection.participantFlowModule.periods.dropWithdraws.reasons.groupId'],
                    # 'flow_drop_wdraw_reason_grp_comment': df_normalized['resultsSection.participantFlowModule.periods.dropWithdraws.comment'],
                    # 'flow_drop_wdraw_reason_grp_num_subject': df_normalized['resultsSection.participantFlowModule.periods.dropWithdraws.reasons.numSubjects'],

    # baseline characteristics
    
    # 'bsln_groups': df_normalized['resultsSection.baselineCharacteristicsModule.groups'],
    #     'bsln_group_id': df_normalized['resultsSection.baselineCharacteristicsModule.groups.id'],
    #     'bsln_group_title': df_normalized['resultsSection.baselineCharacteristicsModule.groups.title'],
    #     'bsln_group_desc': df_normalized['resultsSection.baselineCharacteristicsModule.groups.description'],
    
    # 'bsln_denom': df_normalized['resultsSection.baselineCharacteristicsModule.denoms'],
    #     'bsln_denom_units': df_normalized['resultsSection.baselineCharacteristicsModule.denoms.units'],
    #     'bsln_denom_count': df_normalized['resultsSection.baselineCharacteristicsModule.denoms.counts'],
    
    #         'bsln_denom_grp_id': df_normalized['resultsSection.baselineCharacteristicsModule.denoms.counts.groupId'],
    #         'bsln_denom_group_count': df_normalized['resultsSection.baselineCharacteristicsModule.denoms.counts.value'],

     # 'bsln_measures': df_normalized['resultsSection.baselineCharacteristicsModule.measures'],
     #    'bsln_measures_title': df_normalized['resultsSection.baselineCharacteristicsModule.measures.title'],
     #    'bsln_measures_desc': df_normalized['resultsSection.baselineCharacteristicsModule.measures.description'],
     #    'bsln_measures_pop_desc': df_normalized['resultsSection.baselineCharacteristicsModule.measures.populationDescription'],

     #    'bsln_measures_param_type': df_normalized['resultsSection.baselineCharacteristicsModule.measures.paramType'],
     #    'bsln_dispersion_type': df_normalized['resultsSection.baselineCharacteristicsModule.measures.dispersionType'],
     #    'bsln_measures_unit_of_meas': df_normalized['resultsSection.baselineCharacteristicsModule.measures.unitOfMeasure'],

     #    'bsln_measures_calc_pct': df_normalized['resultsSection.baselineCharacteristicsModule.measures.calculatePct'],
     #    'bsln_denom_units': df_normalized['resultsSection.baselineCharacteristicsModule.measures.denomUnitsSelected'],
    
     #    'bsln_measure_denoms': df_normalized['resultsSection.baselineCharacteristicsModule.measures.denoms'],
             #    'bsln_measure_denom_units': df_normalized['resultsSection.baselineCharacteristicsModule.measures.denoms.units'],
             #    'bsln_measure_denom_counts': df_normalized['resultsSection.baselineCharacteristicsModule.measures.denoms.counts'],

                    # 'bsln_measure_denom_counts_grp_id': df_normalized['resultsSection.baselineCharacteristicsModule.measures.denoms.counts.groupId'],
                    # 'bsln_measure_denom_counts_value': df_normalized['resultsSection.baselineCharacteristicsModule.measures.denoms.counts.value'],
    #    'bsln_class': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes'],
    #    'bsln_class_title': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.denoms'],
    #        'bsln_class_denom_units': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.denoms.units'],
    #        'bsln_class_denom_counts': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.denoms.counts'],

    #            'bsln_class_denom_count_grp_id': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.denoms.counts.groupId'],
    #            'bsln_class_denom_count_value': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.denoms.counts.value'],

    # 'bsln_category': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories'],
    #     'bsln_category_title': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.title'],
    #     'bsln_category_measurments': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurments'],

    #         'bsln_meas_group_id': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurments.groupId'],
    #         'bsln_meas_value': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurments.value'],
    #         'bsln_meas_spread': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurments.spread'],
    #         'bsln_meas_value': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurments.value'],
    #         'bsln_meas_u_limit': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurments.upperLimit'],
    #         'bsln_meas_l_limit': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurments.lowerLimit'],
    #         'bsln_meas_comment': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurments.comment'],
    
    # outcome measures
    # resultsSection.outcomeMeasuresModule.outcomeMeasures

    # 'outcome_measure_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.type'],
    # 'outcome_measure_title': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.title'],
    # 'outcome_measure_desc': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.description'],
    # 'outcome_measure_pop_desc': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.populationDescription'],
    # 'outcome_measure_reporting_status': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.reportingStatus'],
    # 'outcome_measure_antic_posting_date': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.anticipatedPostingDate'],
    # 'outcome_measure_param_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.paramType'],
    # 'outcome_measure_dispersion_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.dispersionType'],
    # 'outcome_measure_unit_of_meas': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.unitOfMeasure'],
    # 'outcome_measure_calc_pct': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.calculatePct'],
    # 'outcome_measure_time_frame': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.timeFrame'],
    # 'outcome_measure_type_units_analyzed': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.typeUnitsAnalyzed'],
    # 'outcome_measure_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.denomUnitsSelected'],
    
        # groups: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.groups'
            'outcome_group_id': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.groups.id'],
            'outcome_group_title': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.groups.title'],
            'outcome_group_desc': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.groups.description'],
            
        # denoms: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.groups'
            'outcome_denom_unit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.denoms.units'],
            # denom_counts: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.denoms.counts'
                'outcome_denom_count_group_id': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.denoms.counts.groupId'],
                'outcome_denom_count_group_value': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.denoms.counts.value'],

    # outcome class: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes'
    'outcome_class_title': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.title'],

        # outcome class denoms: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.denoms'
        'outcome_cls_denoms_unit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.denoms.units'],

            # outcome class denoms counts: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.denoms.counts'
                'outcome_cls_denom_count_group_id': df_normalized['	resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.denoms.counts.groupId'],
                'outcome_cls_denom_count_group_count_value': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.groups.value'],
    
    
    # outcome category: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories'
    'outcome_categories_title': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.categories.title'],

         # outcome category measurments: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements'
        'outcome_meas_group_id': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.value'],
        'outcome_meas_value': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.groupId'],
        'outcome_meas_spread': df_normalized['	resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.spread'],

        'outcome_meas_u_limit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.spread'],
        'outcome_meas_l_limit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.lowerLimit'],
        'outcome_meas_comment': df_normalized['	resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.comment'],

     # resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses
     'outcome_anlys_grp_id': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.groupIds'],
     'outcome_anlys_param_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.paramType'],
     'outcome_anlys_param_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.paramValue'],

     'outcome_anlys_dispersion_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.dispersionType'],
     'outcome_anlys_dispersion_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.dispersionValue'],
     'outcome_anlys_stat_method': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.statisticalMethod'],
     'outcome_anlys_stat_comment': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.statisticalComment'],
     'outcome_anlys_p_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.pValue'],
     'outcome_anlys_p_val_comment': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.pValueComment'],
     'outcome_anlys_ci_num_sides': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciNumSides'],
     'outcome_anlys_ci_pct_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciPctValue'],
     'outcome_anlys_ci_u_limit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciUpperLimit'],
     'outcome_anlys_ci_l_limit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciLowerLimit'],
     'outcome_anlys_ci_u_limit_cmt': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciUpperLimitComment'],
     'outcome_anlys_ci_l_limit_cmt': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciLowerLimitComment'],
     'outcome_anlys_estiate_cmt': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.estimateComment'],
     'outcome_anlys_tested_ni': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.testedNonInferiority'],
     'outcome_anlys_ni_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.nonInferiorityType'],
     'outcome_anlys_ni_cmt': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.nonInferiorityComment'],

    'outcome_anlys_other_anlys_desc': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.otherAnalysisDescription'],
    'outcome_anlys_other_anlys_grp_desc': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.groupDescription'],
    
    
    'last_updated': df_normalized['protocolSection.statusModule.lastUpdatePostDateStruct.date']
})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 274
#       1 study_df = pd.DataFrame({
#       2     #identification
#       3     'nct_id': df_normalized['protocolSection.identificationModule.nctId'],
#       4     'title': df_normalized['protocolSection.identificationModule.officialTitle'],
#       5     'acronym': df_normalized['protocolSection.identificationModule.acronym'],
#       6     'organization_name': df_normalized['protocolSection.identificationModule.organization.fullName'],
#       7     'organization_type': df_normalized['protocolSection.identificationModule.organization.class'],
#       8
#       9     #sponsors and collaborators
#      10     'sponsor_name': df_normalized['protocolSection.sponsorCollaboratorsModule.leadSponsor.name'],
#      11     'sponsor_type': df_normalized['protocolSection.sponsorCollaboratorsModule.leadSponsor.class'],
#      12
#      13     #description
#      14     'brief_summary': df_normalized['protocolSection.descriptionModule.briefSummary'],
#      15     'detailed_description': df_normalized['protocolSection.descriptionModule.detailedDescription'],
#      16
#      17     #conditions
#      18     'condition': df_normalized['protocolSection.conditionsModule.conditions'],
#      19     'keyword': df_normalized['protocolSection.conditionsModule.keywords'],
#      20
#      21     #design
#      22     'study_type': df_normalized['protocolSection.designModule.studyType'],
#      23     'patient_registry': df_normalized['protocolSection.designModule.patientRegistry'],
#      24     'target_duration': df_normalized['protocolSection.designModule.targetDuration'],
#      25     'study_phase': df_normalized['protocolSection.designModule.targetDuration'],
#      26
#      27     'design_allocation': df_normalized['protocolSection.designModule.designInfo.allocation'],
#      28     'design_intervention_model': df_normalized['protocolSection.designModule.designInfo.interventionModel'],
#      29     'design_intervention_model_desc': df_normalized['protocolSection.designModule.designInfo.interventionModelDescription'],
#      30
#      31     'design_primary_purpose': df_normalized['protocolSection.designModule.designInfo.primaryPurpose'],
#      32     'design_observational_model': df_normalized['protocolSection.designModule.designInfo.observationalModel'],
#      33     'design_time_perspective': df_normalized['protocolSection.designModule.designInfo.timePerspective'],
#      34     'design_masking': df_normalized['protocolSection.designModule.designInfo.maskingInfo.masking'],
#      35     'design_masking_decsription': df_normalized['protocolSection.designModule.designInfo.maskingInfo.maskingDescription'],
#      36     'design_who_masked': df_normalized['protocolSection.designModule.designInfo.maskingInfo.whoMasked'],
#      37
#      38      #expanded access
#      39     'exp_acc_type_intermediate': df_normalized['protocolSection.designModule.expandedAccessTypes.intermediate'],
#      40     'exp_acc_type_treatment': df_normalized['protocolSection.designModule.expandedAccessTypes.treatment'],
#      41
#      42     #Biospec
#      43     'biospec_retention': df_normalized['protocolSection.designModule.bioSpec.retention'],
#      44     'biospec_description': df_normalized['protocolSection.designModule.bioSpec.description'],
#      45
#      46     #enrollment
#      47     'enrollment_type': df_normalized['protocolSection.designModule.enrollmentInfo.type'],
#      48     'enrollment_count': df_normalized['protocolSection.designModule.enrollmentInfo.count'],
#      49
#      50     #arm group
#      51     'arm_group_label': df_normalized['protocolSection.designModule.enrollmentInfo.type'],
#      52     'arm_group_type': df_normalized['protocolSection.designModule.enrollmentInfo.count'],
#      53
#      54      #eligibility
#      55     'eligibility_criteria': df_normalized['protocolSection.eligibilityModule.eligibilityCriteria'],
#      56     'healthy_volunteers': df_normalized['protocolSection.eligibilityModule.healthyVolunteers'],
#      57
#      58     'sex': df_normalized['protocolSection.eligibilityModule.sex'],
#      59     'gender_based': df_normalized['protocolSection.eligibilityModule.genderBased'],
#      60     'gender_description': df_normalized['protocolSection.eligibilityModule.genderDescription'],
#      61     'min_age': df_normalized['protocolSection.eligibilityModule.genderBased'],
#      62     'max_age': df_normalized['protocolSection.eligibilityModule.sex'],
#      63     'population_description': df_normalized['protocolSection.eligibilityModule.studyPopulation'],
#      64     'sampling_method': df_normalized['protocolSection.eligibilityModule.samplingMethod'],
#      65
#      66      #status
#      67     'overall_status': df_normalized['protocolSection.statusModule.lastKnownStatus'],
#      68     'last_known_status': df_normalized['protocolSection.statusModule.lastKnownStatus'],
#      69
#      70     'start_date': df_normalized['protocolSection.statusModule.startDateStruct.date'],
#      71     'start_date_type': df_normalized['protocolSection.statusModule.startDateStruct.type'],
#      72
#      73     'first_submit_date': df_normalized['protocolSection.statusModule.studyFirstSubmitDate'],
#      74     'first_submit_qc_date': df_normalized['protocolSection.statusModule.studyFirstSubmitQcDate'],
#      75
#      76     'last_update_submit': df_normalized['protocolSection.statusModule.lastUpdateSubmitDate'],
#      77     'completion_date': df_normalized['protocolSection.statusModule.completionDateStruct.date'],
#      78     'completion_date_type': df_normalized['protocolSection.statusModule.completionDateStruct.type'],
#      79
#      80     'why_stopped': df_normalized['protocolSection.statusModule.whyStopped'],
#      81     'has_exp_access': df_normalized['protocolSection.statusModule.expandedAccessInfo.hasExpandedAccess'],
#      82
#      83      #oversight
#      84     'has_dmc': df_normalized['protocolSection.oversightModule.oversightHasDmc'],
#      85     'is_fda_regulated_drug': df_normalized['protocolSection.oversightModule.isFdaRegulatedDrug'],
#      86     'is_fda_regulated_device': df_normalized['protocolSection.oversightModule.isFdaRegulatedDevice'],
#      87     'is_unapproved_device': df_normalized['protocolSection.oversightModule.isUnapprovedDevice'],
#      88
#      89     # individual participant data
#      90     'ipd_sharing': df_normalized['protocolSection.ipdSharingStatementModule.ipdSharing'],
#      91     'ipd_sharing_description': df_normalized['protocolSection.ipdSharingStatementModule.description'],
#      92     'ipd_sharing_info_type': df_normalized['protocolSection.ipdSharingStatementModule.infoTypes'],
#      93     'ipd_sharing_time_frame': df_normalized['protocolSection.ipdSharingStatementModule.timeFrame'],
#      94     'ipd_sharing_access_criteria': df_normalized['protocolSection.ipdSharingStatementModule.accessCriteria'],
#      95     'ipd_sharing_url': df_normalized['protocolSection.ipdSharingStatementModule.url'],
#      96
#      97     # results
#      98     'ipd_sharing': df_normalized['protocolSection.ipdSharingStatementModule.ipdSharing'],
#      99     'ipd_sharing_description': df_normalized['protocolSection.ipdSharingStatementModule.description'],
#     100     'ipd_sharing_info_type': df_normalized['protocolSection.ipdSharingStatementModule.infoTypes'],
#     101     'ipd_sharing_time_frame': df_normalized['protocolSection.ipdSharingStatementModule.timeFrame'],
#     102
#     103
#     104     # participant_flow
#     105     'flow_pre_assignment_details': df_normalized['resultsSection.participantFlowModule.preAssignmentDetails'],
#     106     'flow_recruitment_details': df_normalized['resultsSection.participantFlowModule.recruitmentDetails'],
#     107     'flow_type_unit_analysed': df_normalized['resultsSection.participantFlowModule.typeUnitsAnalyzed'],
#     108
#     109      # baseline characteristics
#     110     'bsln_pop_desc': df_normalized['resultsSection.baselineCharacteristicsModule.populationDescription'],
#     111     'bsln_pop_units_analysed': df_normalized['resultsSection.baselineCharacteristicsModule.typeUnitsAnalyzed'],
#     112
#     113     #sponsors and collaborators
#     114     # 'collaborator_name': df_normalized['protocolSection.sponsorCollaboratorsModule.collaborators.name'],
#     115     # 'collaborator_type': df_normalized['protocolSection.sponsorCollaboratorsModule.collaborators.class'],
#     116
#     117     #expanded access
#     118     # 'exp_acc_type_individual': df_normalized['protocolSection.designModule.expandedAccessTypes.individual'],
#     119
#     120     #arm group
#     121     # 'arm_group_description': df_normalized['protocolSection.armsInterventionsModule.armGroups.description'],
#     122     # 'arm_group_intervention_names': df_normalized['protocolSection.armsInterventionsModule.armGroups.interventionNames'],
#     123
#     124     #intervention
#     125     # 'intervention_type': df_normalized['protocolSection.armsInterventionsModule.interventions.type'],
#     126     # 'intervention_name': df_normalized['protocolSection.armsInterventionsModule.interventions.name'],
#     127     # 'intervention_description': df_normalized['protocolSection.armsInterventionsModule.interventions.description'],
#     128     # 'intervention_arm_group_labels': df_normalized['protocolSection.armsInterventionsModule.interventions.armGroupLabels'],
#     129     # 'intervention_other_names': df_normalized['protocolSection.armsInterventionsModule.interventions.otherNames'],
#     130
#     131     #outcomes
#     132     # 'primary_outcome_measure': df_normalized['protocolSection.outcomesModule.primaryOutcomes.measure'],
#     133     # 'primary_outcome_description': df_normalized['protocolSection.outcomesModule.primaryOutcomes.description'],
#     134     # 'primary_outcome_time_frame': df_normalized['protocolSection.outcomesModule.primaryOutcomes.timeFrame'],
#     135
#     136     # 'secondary_outcome_measure': df_normalized['protocolSection.outcomesModule.secondaryOutcomes.measure'],
#     137     # 'secondary_outcome_description': df_normalized['protocolSection.outcomesModule.secondaryOutcomes.description'],
#     138     # 'secondary_outcome_time_frame': df_normalized['protocolSection.outcomesModule.secondaryOutcomes.timeFrame'],
#     139
#     140     # 'other_outcome_measure': df_normalized['protocolSection.outcomesModule.otherOutcomes.measure'],
#     141     # 'other_outcome_description': df_normalized['protocolSection.outcomesModule.otherOutcomes.description'],
#     142     # 'other_outcome_time_frame': df_normalized['protocolSection.outcomesModule.otherOutcomes.timeFrame'],
#     143
#     144     #central contact
#     145     # 'central_contact_name': df_normalized['protocolSection.contactsLocationsModule.centralContacts.name'],
#     146     # 'central_contact_role': df_normalized['protocolSection.contactsLocationsModule.centralContacts.role'],
#     147     # 'central_contact_phone': df_normalized['protocolSection.contactsLocationsModule.centralContacts.phone'],
#     148     # 'central_contact_phone_ext': df_normalized['protocolSection.contactsLocationsModule.centralContacts.phoneExt'],
#     149     # 'central_contact_email': df_normalized['protocolSection.contactsLocationsModule.centralContacts.email'],
#     150
#     151      #study officials
#     152     # 'official_name': df_normalized['protocolSection.contactsLocationsModule.overallOfficials.name'],
#     153     # 'official_role': df_normalized['protocolSection.contactsLocationsModule.overallOfficials.role'],
#     154     # 'official_affiliation': df_normalized['protocolSection.contactsLocationsModule.overallOfficials.affiliation'],
#     155
#     156     #location
#     157     # 'facility_name': df_normalized['protocolSection.contactsLocationsModule.locations.facility'],
#     158     # 'facility_recruitment_status': df_normalized['protocolSection.contactsLocationsModule.locations.status'],
#     159     # 'facility_city': df_normalized['protocolSection.contactsLocationsModule.locations.city'],
#     160     # 'facility_state': df_normalized['protocolSection.contactsLocationsModule.locations.state'],
#     161     # 'facility_zip': df_normalized['protocolSection.contactsLocationsModule.locations.zip'],
#     162     # 'facility_country': df_normalized['protocolSection.contactsLocationsModule.locations.country'],
#     163
#     164
#     165     #location contacts
#     166     # 'facility_contact_name': df_normalized['protocolSection.contactsLocationsModule.locations.contacts.name'],
#     167     # 'facility_contact_role': df_normalized['protocolSection.contactsLocationsModule.locations.contacts.role'],
#     168     # 'facility_contact_phone': df_normalized['protocolSection.contactsLocationsModule.locations.contacts.phone'],
#     169     # 'facility_contact_phone_ext': df_normalized['protocolSection.contactsLocationsModule.locations.contacts.phoneExt'],
#     170     # 'facility_contact_email': df_normalized['protocolSection.contactsLocationsModule.locations.contacts.email'],
#     171
#     172
#     173     #reference
#     174     # 'ref_pmid': df_normalized['protocolSection.referencesModule.references.pmid'],
#     175     # 'ref_type': df_normalized['protocolSection.referencesModule.references.type'],
#     176     # 'ref_citation': df_normalized['protocolSection.referencesModule.references.citation'],
#     177
#     178     #retraction
#     179     # 'ret_pmid': df_normalized['protocolSection.referencesModule.references.retractions.pmid'],
#     180     # 'ret_source': df_normalized['protocolSection.referencesModule.references.retractions.status'],
#     181
#     182     #see also link
#     183     # 'see_also_label': df_normalized['protocolSection.referencesModule.seeAlsoLinks.label'],
#     184     # 'see_also_url': df_normalized['protocolSection.referencesModule.seeAlsoLinks.url'],
#     185
#     186     #status
#     187     # 'exp_access_id': df_normalized['protocolSection.statusModule.expandedAccessInfo.nctId'],
#     188
#     189     #oversight
#     190     # 'is_ppsd': df_normalized['protocolSection.oversightModule.isPpsd'],
#     191
#     192     # participant_flow
#     193     # 'flow_groups': df_normalized['resultsSection.participantFlowModule.groups'],
#     194           # 'flow_group_id': df_normalized['resultsSection.participantFlowModule.groups.id'],
#     195           # 'flow_group_title': df_normalized['resultsSection.participantFlowModule.groups.title'],
#     196           # 'flow_group_description': df_normalized['resultsSection.participantFlowModule.groups.description'],
#     197
#     198     # 'flow_period': df_normalized['resultsSection.participantFlowModule.periods'],
#     199           # 'flow_period_title': df_normalized['resultsSection.participantFlowModule.periods.title'],
#     200           # 'flow_period_milestone': df_normalized['resultsSection.participantFlowModule.periods.milestones'],
#     201               # 'flow_milestone_type': df_normalized['resultsSection.participantFlowModule.periods.milestones.type'],
#     202               # 'flow_milestone_comment': df_normalized['	resultsSection.participantFlowModule.periods.milestones.comment'],
#     203
#     204           # 'flow_milestone_achievments': df_normalized['	resultsSection.participantFlowModule.periods.milestones.achievements'],
#     205                 # 'flow_achievment_grp_id': df_normalized['	resultsSection.participantFlowModule.periods.milestones.achievements.groupId'],
#     206                 # 'flow_achievment_grp_comment': df_normalized['resultsSection.participantFlowModule.periods.milestones.achievements.comment'],
#     207                 # 'flow_achievment_grp_num_participants': df_normalized['resultsSection.participantFlowModule.periods.milestones.achievements.numSubjects'],
#     208                 # 'flow_achievment_grp_num_units': df_normalized['resultsSection.participantFlowModule.periods.milestones.achievements.numUnits'],
#     209
#     210          # 'flow_drop_withdraws': df_normalized['resultsSection.participantFlowModule.periods.dropWithdraws'],
#     211                # 'flow_drop_withdraw_type': df_normalized['resultsSection.participantFlowModule.periods.dropWithdraws.type'],
#     212                # 'flow_drop_wdraw_comment': df_normalized['resultsSection.participantFlowModule.periods.dropWithdraws.comment'],
#     213
#     214                # 'flow_drop_wdraw_reason': df_normalized['resultsSection.participantFlowModule.periods.dropWithdraws.reasons'],
#     215                     # 'flow_drop_wdraw_reason_grp_id': df_normalized['resultsSection.participantFlowModule.periods.dropWithdraws.reasons.groupId'],
#     216                     # 'flow_drop_wdraw_reason_grp_comment': df_normalized['resultsSection.participantFlowModule.periods.dropWithdraws.comment'],
#     217                     # 'flow_drop_wdraw_reason_grp_num_subject': df_normalized['resultsSection.participantFlowModule.periods.dropWithdraws.reasons.numSubjects'],
#     218
#     219     # baseline characteristics
#     220
#     221     # 'bsln_groups': df_normalized['resultsSection.baselineCharacteristicsModule.groups'],
#     222     #     'bsln_group_id': df_normalized['resultsSection.baselineCharacteristicsModule.groups.id'],
#     223     #     'bsln_group_title': df_normalized['resultsSection.baselineCharacteristicsModule.groups.title'],
#     224     #     'bsln_group_desc': df_normalized['resultsSection.baselineCharacteristicsModule.groups.description'],
#     225
#     226     # 'bsln_denom': df_normalized['resultsSection.baselineCharacteristicsModule.denoms'],
#     227     #     'bsln_denom_units': df_normalized['resultsSection.baselineCharacteristicsModule.denoms.units'],
#     228     #     'bsln_denom_count': df_normalized['resultsSection.baselineCharacteristicsModule.denoms.counts'],
#     229
#     230     #         'bsln_denom_grp_id': df_normalized['resultsSection.baselineCharacteristicsModule.denoms.counts.groupId'],
#     231     #         'bsln_denom_group_count': df_normalized['resultsSection.baselineCharacteristicsModule.denoms.counts.value'],
#     232
#     233      # 'bsln_measures': df_normalized['resultsSection.baselineCharacteristicsModule.measures'],
#     234      #    'bsln_measures_title': df_normalized['resultsSection.baselineCharacteristicsModule.measures.title'],
#     235      #    'bsln_measures_desc': df_normalized['resultsSection.baselineCharacteristicsModule.measures.description'],
#     236      #    'bsln_measures_pop_desc': df_normalized['resultsSection.baselineCharacteristicsModule.measures.populationDescription'],
#     237
#     238      #    'bsln_measures_param_type': df_normalized['resultsSection.baselineCharacteristicsModule.measures.paramType'],
#     239      #    'bsln_dispersion_type': df_normalized['resultsSection.baselineCharacteristicsModule.measures.dispersionType'],
#     240      #    'bsln_measures_unit_of_meas': df_normalized['resultsSection.baselineCharacteristicsModule.measures.unitOfMeasure'],
#     241
#     242      #    'bsln_measures_calc_pct': df_normalized['resultsSection.baselineCharacteristicsModule.measures.calculatePct'],
#     243      #    'bsln_denom_units': df_normalized['resultsSection.baselineCharacteristicsModule.measures.denomUnitsSelected'],
#     244
#     245      #    'bsln_measure_denoms': df_normalized['resultsSection.baselineCharacteristicsModule.measures.denoms'],
#     246              #    'bsln_measure_denom_units': df_normalized['resultsSection.baselineCharacteristicsModule.measures.denoms.units'],
#     247              #    'bsln_measure_denom_counts': df_normalized['resultsSection.baselineCharacteristicsModule.measures.denoms.counts'],
#     248
#     249                     # 'bsln_measure_denom_counts_grp_id': df_normalized['resultsSection.baselineCharacteristicsModule.measures.denoms.counts.groupId'],
#     250                     # 'bsln_measure_denom_counts_value': df_normalized['resultsSection.baselineCharacteristicsModule.measures.denoms.counts.value'],
#     251     #    'bsln_class': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes'],
#     252     #    'bsln_class_title': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.denoms'],
#     253     #        'bsln_class_denom_units': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.denoms.units'],
#     254     #        'bsln_class_denom_counts': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.denoms.counts'],
#     255
#     256     #            'bsln_class_denom_count_grp_id': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.denoms.counts.groupId'],
#     257     #            'bsln_class_denom_count_value': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.denoms.counts.value'],
#     258
#     259     # 'bsln_category': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories'],
#     260     #     'bsln_category_title': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.title'],
#     261     #     'bsln_category_measurments': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurments'],
#     262
#     263     #         'bsln_meas_group_id': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurments.groupId'],
#     264     #         'bsln_meas_value': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurments.value'],
#     265     #         'bsln_meas_spread': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurments.spread'],
#     266     #         'bsln_meas_value': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurments.value'],
#     267     #         'bsln_meas_u_limit': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurments.upperLimit'],
#     268     #         'bsln_meas_l_limit': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurments.lowerLimit'],
#     269     #         'bsln_meas_comment': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurments.comment'],
#     270
#     271     # outcome measures
#     272     # resultsSection.outcomeMeasuresModule.outcomeMeasures
#     273
# --> 274     'outcome_measure_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.type'],
#     275     'outcome_measure_title': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.title'],
#     276     'outcome_measure_desc': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.description'],
#     277     'outcome_measure_pop_desc': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.populationDescription'],
#     278     'outcome_measure_reporting_status': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.reportingStatus'],
#     279     'outcome_measure_antic_posting_date': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.anticipatedPostingDate'],
#     280     'outcome_measure_param_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.paramType'],
#     281     'outcome_measure_dispersion_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.dispersionType'],
#     282     'outcome_measure_unit_of_meas': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.unitOfMeasure'],
#     283     'outcome_measure_calc_pct': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.calculatePct'],
#     284     'outcome_measure_time_frame': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.timeFrame'],
#     285     'outcome_measure_type_units_analyzed': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.typeUnitsAnalyzed'],
#     286     'outcome_measure_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.denomUnitsSelected'],
#     287
#     288         # groups: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.groups'
#     289             'outcome_group_id': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.groups.id'],
#     290             'outcome_group_title': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.groups.title'],
#     291             'outcome_group_desc': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.groups.description'],
#     292
#     293         # denoms: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.groups'
#     294             'outcome_denom_unit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.denoms.units'],
#     295             # denom_counts: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.denoms.counts'
#     296                 'outcome_denom_count_group_id': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.denoms.counts.groupId'],
#     297                 'outcome_denom_count_group_value': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.denoms.counts.value'],
#     298
#     299     # outcome class: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes'
#     300     'outcome_class_title': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.title'],
#     301
#     302         # outcome class denoms: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.denoms'
#     303         'outcome_cls_denoms_unit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.denoms.units'],
#     304
#     305             # outcome class denoms counts: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.denoms.counts'
#     306                 'outcome_cls_denom_count_group_id': df_normalized['	resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.denoms.counts.groupId'],
#     307                 'outcome_cls_denom_count_group_count_value': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.groups.value'],
#     308
#     309
#     310     # outcome category: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories'
#     311     'outcome_categories_title': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.categories.title'],
#     312
#     313          # outcome category measurments: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements'
#     314         'outcome_meas_group_id': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.value'],
#     315         'outcome_meas_value': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.groupId'],
#     316         'outcome_meas_spread': df_normalized['	resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.spread'],
#     317
#     318         'outcome_meas_u_limit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.spread'],
#     319         'outcome_meas_l_limit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.lowerLimit'],
#     320         'outcome_meas_comment': df_normalized['	resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.comment'],
#     321
#     322      # resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses
#     323      'outcome_anlys_param_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.paramType'],
#     324      'outcome_anlys_param_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.paramValue'],
#     325
#     326      'outcome_anlys_dispersion_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.dispersionType'],
#     327      'outcome_anlys_dispersion_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.dispersionValue'],
#     328     'outcome_anlys_dispersion_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.dispersionType'],
#     329      'outcome_anlys_dispersion_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.dispersionValue'],
#     330     'outcome_anlys_dispersion_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.dispersionType'],
#     331      'outcome_anlys_dispersion_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.dispersionValue'],
#     332     'outcome_anlys_dispersion_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.dispersionType'],
#     333      'outcome_anlys_dispersion_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.dispersionValue'],
#     334
#     335
#     336
#     337
#     338
#     339
#     340     'last_updated': df_normalized['protocolSection.statusModule.lastUpdatePostDateStruct.date']
#     341 })
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.type'

# %%
# print(study_df.head(6))

# %%
study_df.head(20).to_csv("sample.csv", index=False)

# %%
transposed = (study_df.transpose())
