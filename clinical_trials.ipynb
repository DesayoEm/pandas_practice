# %%
import pandas as pd
import pyarrow.parquet as pq

# %%
pf = pq.ParquetFile("page1.parquet")

# %%
print(pf.schema)
# Out:
# <pyarrow._parquet.ParquetSchema object at 0x000001E37DCC6F40>
# required group field_id=-1 schema {
#   optional group field_id=-1 studies {
#     optional group field_id=-1 annotationSection {
#       optional group field_id=-1 annotationModule {
#         optional group field_id=-1 unpostedAnnotation {
#           optional group field_id=-1 unpostedEvents (List) {
#             repeated group field_id=-1 list {
#               optional group field_id=-1 element {
#                 optional binary field_id=-1 date (String);
#                 optional binary field_id=-1 type (String);
#               }
#             }
#           }
#           optional binary field_id=-1 unpostedResponsibleParty (String);
#         }
#       }
#     }
#     optional group field_id=-1 derivedSection {
#       optional group field_id=-1 conditionBrowseModule {
#         optional group field_id=-1 ancestors (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 id (String);
#               optional binary field_id=-1 term (String);
#             }
#           }
#         }
#         optional group field_id=-1 meshes (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 id (String);
#               optional binary field_id=-1 term (String);
#             }
#           }
#         }
#       }
#       optional group field_id=-1 interventionBrowseModule {
#         optional group field_id=-1 ancestors (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 id (String);
#               optional binary field_id=-1 term (String);
#             }
#           }
#         }
#         optional group field_id=-1 meshes (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 id (String);
#               optional binary field_id=-1 term (String);
#             }
#           }
#         }
#       }
#       optional group field_id=-1 miscInfoModule {
#         optional group field_id=-1 removedCountries (List) {
#           repeated group field_id=-1 list {
#             optional binary field_id=-1 element (String);
#           }
#         }
#         optional group field_id=-1 submissionTracking {
#           optional binary field_id=-1 estimatedResultsFirstSubmitDate (String);
#           optional group field_id=-1 firstMcpInfo {
#             optional group field_id=-1 postDateStruct {
#               optional binary field_id=-1 date (String);
#               optional binary field_id=-1 type (String);
#             }
#           }
#           optional group field_id=-1 submissionInfos (List) {
#             repeated group field_id=-1 list {
#               optional group field_id=-1 element {
#                 optional int64 field_id=-1 mcpReleaseN;
#                 optional binary field_id=-1 releaseDate (String);
#                 optional binary field_id=-1 resetDate (String);
#               }
#             }
#           }
#         }
#         optional binary field_id=-1 versionHolder (String);
#       }
#     }
#     optional group field_id=-1 documentSection {
#       optional group field_id=-1 largeDocumentModule {
#         optional group field_id=-1 largeDocs (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 date (String);
#               optional binary field_id=-1 filename (String);
#               optional boolean field_id=-1 hasIcf;
#               optional boolean field_id=-1 hasProtocol;
#               optional boolean field_id=-1 hasSap;
#               optional binary field_id=-1 label (String);
#               optional int64 field_id=-1 size;
#               optional binary field_id=-1 typeAbbrev (String);
#               optional binary field_id=-1 uploadDate (String);
#             }
#           }
#         }
#         optional boolean field_id=-1 noSap;
#       }
#     }
#     optional boolean field_id=-1 hasResults;
#     optional group field_id=-1 protocolSection {
#       optional group field_id=-1 armsInterventionsModule {
#         optional group field_id=-1 armGroups (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 description (String);
#               optional group field_id=-1 interventionNames (List) {
#                 repeated group field_id=-1 list {
#                   optional binary field_id=-1 element (String);
#                 }
#               }
#               optional binary field_id=-1 label (String);
#               optional binary field_id=-1 type (String);
#             }
#           }
#         }
#         optional group field_id=-1 interventions (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional group field_id=-1 armGroupLabels (List) {
#                 repeated group field_id=-1 list {
#                   optional binary field_id=-1 element (String);
#                 }
#               }
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 name (String);
#               optional group field_id=-1 otherNames (List) {
#                 repeated group field_id=-1 list {
#                   optional binary field_id=-1 element (String);
#                 }
#               }
#               optional binary field_id=-1 type (String);
#             }
#           }
#         }
#       }
#       optional group field_id=-1 conditionsModule {
#         optional group field_id=-1 conditions (List) {
#           repeated group field_id=-1 list {
#             optional binary field_id=-1 element (String);
#           }
#         }
#         optional group field_id=-1 keywords (List) {
#           repeated group field_id=-1 list {
#             optional binary field_id=-1 element (String);
#           }
#         }
#       }
#       optional group field_id=-1 contactsLocationsModule {
#         optional group field_id=-1 centralContacts (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 email (String);
#               optional binary field_id=-1 name (String);
#               optional binary field_id=-1 phone (String);
#               optional binary field_id=-1 phoneExt (String);
#               optional binary field_id=-1 role (String);
#             }
#           }
#         }
#         optional group field_id=-1 locations (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 city (String);
#               optional group field_id=-1 contacts (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional binary field_id=-1 email (String);
#                     optional binary field_id=-1 name (String);
#                     optional binary field_id=-1 phone (String);
#                     optional binary field_id=-1 phoneExt (String);
#                     optional binary field_id=-1 role (String);
#                   }
#                 }
#               }
#               optional binary field_id=-1 country (String);
#               optional binary field_id=-1 facility (String);
#               optional group field_id=-1 geoPoint {
#                 optional double field_id=-1 lat;
#                 optional double field_id=-1 lon;
#               }
#               optional binary field_id=-1 state (String);
#               optional binary field_id=-1 status (String);
#               optional binary field_id=-1 zip (String);
#             }
#           }
#         }
#         optional group field_id=-1 overallOfficials (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 affiliation (String);
#               optional binary field_id=-1 name (String);
#               optional binary field_id=-1 role (String);
#             }
#           }
#         }
#       }
#       optional group field_id=-1 descriptionModule {
#         optional binary field_id=-1 briefSummary (String);
#         optional binary field_id=-1 detailedDescription (String);
#       }
#       optional group field_id=-1 designModule {
#         optional group field_id=-1 bioSpec {
#           optional binary field_id=-1 description (String);
#           optional binary field_id=-1 retention (String);
#         }
#         optional group field_id=-1 designInfo {
#           optional binary field_id=-1 allocation (String);
#           optional binary field_id=-1 interventionModel (String);
#           optional binary field_id=-1 interventionModelDescription (String);
#           optional group field_id=-1 maskingInfo {
#             optional binary field_id=-1 masking (String);
#             optional binary field_id=-1 maskingDescription (String);
#             optional group field_id=-1 whoMasked (List) {
#               repeated group field_id=-1 list {
#                 optional binary field_id=-1 element (String);
#               }
#             }
#           }
#           optional binary field_id=-1 observationalModel (String);
#           optional binary field_id=-1 primaryPurpose (String);
#           optional binary field_id=-1 timePerspective (String);
#         }
#         optional group field_id=-1 enrollmentInfo {
#           optional int64 field_id=-1 count;
#           optional binary field_id=-1 type (String);
#         }
#         optional group field_id=-1 expandedAccessTypes {
#           optional boolean field_id=-1 intermediate;
#           optional boolean field_id=-1 treatment;
#         }
#         optional boolean field_id=-1 patientRegistry;
#         optional group field_id=-1 phases (List) {
#           repeated group field_id=-1 list {
#             optional binary field_id=-1 element (String);
#           }
#         }
#         optional binary field_id=-1 studyType (String);
#         optional binary field_id=-1 targetDuration (String);
#       }
#       optional group field_id=-1 eligibilityModule {
#         optional binary field_id=-1 eligibilityCriteria (String);
#         optional boolean field_id=-1 genderBased;
#         optional binary field_id=-1 genderDescription (String);
#         optional boolean field_id=-1 healthyVolunteers;
#         optional binary field_id=-1 maximumAge (String);
#         optional binary field_id=-1 minimumAge (String);
#         optional binary field_id=-1 samplingMethod (String);
#         optional binary field_id=-1 sex (String);
#         optional group field_id=-1 stdAges (List) {
#           repeated group field_id=-1 list {
#             optional binary field_id=-1 element (String);
#           }
#         }
#         optional binary field_id=-1 studyPopulation (String);
#       }
#       optional group field_id=-1 identificationModule {
#         optional binary field_id=-1 acronym (String);
#         optional binary field_id=-1 briefTitle (String);
#         optional binary field_id=-1 nctId (String);
#         optional group field_id=-1 nctIdAliases (List) {
#           repeated group field_id=-1 list {
#             optional binary field_id=-1 element (String);
#           }
#         }
#         optional binary field_id=-1 officialTitle (String);
#         optional group field_id=-1 orgStudyIdInfo {
#           optional binary field_id=-1 id (String);
#           optional binary field_id=-1 link (String);
#           optional binary field_id=-1 type (String);
#         }
#         optional group field_id=-1 organization {
#           optional binary field_id=-1 class (String);
#           optional binary field_id=-1 fullName (String);
#         }
#         optional group field_id=-1 secondaryIdInfos (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 domain (String);
#               optional binary field_id=-1 id (String);
#               optional binary field_id=-1 link (String);
#               optional binary field_id=-1 type (String);
#             }
#           }
#         }
#       }
#       optional group field_id=-1 ipdSharingStatementModule {
#         optional binary field_id=-1 accessCriteria (String);
#         optional binary field_id=-1 description (String);
#         optional group field_id=-1 infoTypes (List) {
#           repeated group field_id=-1 list {
#             optional binary field_id=-1 element (String);
#           }
#         }
#         optional binary field_id=-1 ipdSharing (String);
#         optional binary field_id=-1 timeFrame (String);
#         optional binary field_id=-1 url (String);
#       }
#       optional group field_id=-1 outcomesModule {
#         optional group field_id=-1 otherOutcomes (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 measure (String);
#               optional binary field_id=-1 timeFrame (String);
#             }
#           }
#         }
#         optional group field_id=-1 primaryOutcomes (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 measure (String);
#               optional binary field_id=-1 timeFrame (String);
#             }
#           }
#         }
#         optional group field_id=-1 secondaryOutcomes (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 measure (String);
#               optional binary field_id=-1 timeFrame (String);
#             }
#           }
#         }
#       }
#       optional group field_id=-1 oversightModule {
#         optional boolean field_id=-1 isFdaRegulatedDevice;
#         optional boolean field_id=-1 isFdaRegulatedDrug;
#         optional boolean field_id=-1 isUnapprovedDevice;
#         optional boolean field_id=-1 isUsExport;
#         optional boolean field_id=-1 oversightHasDmc;
#       }
#       optional group field_id=-1 referencesModule {
#         optional group field_id=-1 availIpds (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 comment (String);
#               optional binary field_id=-1 id (String);
#               optional binary field_id=-1 type (String);
#               optional binary field_id=-1 url (String);
#             }
#           }
#         }
#         optional group field_id=-1 references (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 citation (String);
#               optional binary field_id=-1 pmid (String);
#               optional binary field_id=-1 type (String);
#             }
#           }
#         }
#         optional group field_id=-1 seeAlsoLinks (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 label (String);
#               optional binary field_id=-1 url (String);
#             }
#           }
#         }
#       }
#       optional group field_id=-1 sponsorCollaboratorsModule {
#         optional group field_id=-1 collaborators (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 class (String);
#               optional binary field_id=-1 name (String);
#             }
#           }
#         }
#         optional group field_id=-1 leadSponsor {
#           optional binary field_id=-1 class (String);
#           optional binary field_id=-1 name (String);
#         }
#         optional group field_id=-1 responsibleParty {
#           optional binary field_id=-1 investigatorAffiliation (String);
#           optional binary field_id=-1 investigatorFullName (String);
#           optional binary field_id=-1 investigatorTitle (String);
#           optional binary field_id=-1 oldNameTitle (String);
#           optional binary field_id=-1 oldOrganization (String);
#           optional binary field_id=-1 type (String);
#         }
#       }
#       optional group field_id=-1 statusModule {
#         optional group field_id=-1 completionDateStruct {
#           optional binary field_id=-1 date (String);
#           optional binary field_id=-1 type (String);
#         }
#         optional boolean field_id=-1 delayedPosting;
#         optional group field_id=-1 dispFirstPostDateStruct {
#           optional binary field_id=-1 date (String);
#           optional binary field_id=-1 type (String);
#         }
#         optional binary field_id=-1 dispFirstSubmitDate (String);
#         optional binary field_id=-1 dispFirstSubmitQcDate (String);
#         optional group field_id=-1 expandedAccessInfo {
#           optional boolean field_id=-1 hasExpandedAccess;
#         }
#         optional binary field_id=-1 lastKnownStatus (String);
#         optional group field_id=-1 lastUpdatePostDateStruct {
#           optional binary field_id=-1 date (String);
#           optional binary field_id=-1 type (String);
#         }
#         optional binary field_id=-1 lastUpdateSubmitDate (String);
#         optional binary field_id=-1 overallStatus (String);
#         optional group field_id=-1 primaryCompletionDateStruct {
#           optional binary field_id=-1 date (String);
#           optional binary field_id=-1 type (String);
#         }
#         optional group field_id=-1 resultsFirstPostDateStruct {
#           optional binary field_id=-1 date (String);
#           optional binary field_id=-1 type (String);
#         }
#         optional binary field_id=-1 resultsFirstSubmitDate (String);
#         optional binary field_id=-1 resultsFirstSubmitQcDate (String);
#         optional group field_id=-1 startDateStruct {
#           optional binary field_id=-1 date (String);
#           optional binary field_id=-1 type (String);
#         }
#         optional binary field_id=-1 statusVerifiedDate (String);
#         optional group field_id=-1 studyFirstPostDateStruct {
#           optional binary field_id=-1 date (String);
#           optional binary field_id=-1 type (String);
#         }
#         optional binary field_id=-1 studyFirstSubmitDate (String);
#         optional binary field_id=-1 studyFirstSubmitQcDate (String);
#         optional binary field_id=-1 whyStopped (String);
#       }
#     }
#     optional group field_id=-1 resultsSection {
#       optional group field_id=-1 adverseEventsModule {
#         optional binary field_id=-1 description (String);
#         optional group field_id=-1 eventGroups (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional int64 field_id=-1 deathsNumAffected;
#               optional int64 field_id=-1 deathsNumAtRisk;
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 id (String);
#               optional int64 field_id=-1 otherNumAffected;
#               optional int64 field_id=-1 otherNumAtRisk;
#               optional int64 field_id=-1 seriousNumAffected;
#               optional int64 field_id=-1 seriousNumAtRisk;
#               optional binary field_id=-1 title (String);
#             }
#           }
#         }
#         optional binary field_id=-1 frequencyThreshold (String);
#         optional group field_id=-1 otherEvents (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 assessmentType (String);
#               optional binary field_id=-1 notes (String);
#               optional binary field_id=-1 organSystem (String);
#               optional binary field_id=-1 sourceVocabulary (String);
#               optional group field_id=-1 stats (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional binary field_id=-1 groupId (String);
#                     optional int64 field_id=-1 numAffected;
#                     optional int64 field_id=-1 numAtRisk;
#                     optional int64 field_id=-1 numEvents;
#                   }
#                 }
#               }
#               optional binary field_id=-1 term (String);
#             }
#           }
#         }
#         optional group field_id=-1 seriousEvents (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 assessmentType (String);
#               optional binary field_id=-1 notes (String);
#               optional binary field_id=-1 organSystem (String);
#               optional binary field_id=-1 sourceVocabulary (String);
#               optional group field_id=-1 stats (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional binary field_id=-1 groupId (String);
#                     optional int64 field_id=-1 numAffected;
#                     optional int64 field_id=-1 numAtRisk;
#                     optional int64 field_id=-1 numEvents;
#                   }
#                 }
#               }
#               optional binary field_id=-1 term (String);
#             }
#           }
#         }
#         optional binary field_id=-1 timeFrame (String);
#       }
#       optional group field_id=-1 baselineCharacteristicsModule {
#         optional group field_id=-1 denoms (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional group field_id=-1 counts (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional binary field_id=-1 groupId (String);
#                     optional binary field_id=-1 value (String);
#                   }
#                 }
#               }
#               optional binary field_id=-1 units (String);
#             }
#           }
#         }
#         optional group field_id=-1 groups (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 id (String);
#               optional binary field_id=-1 title (String);
#             }
#           }
#         }
#         optional group field_id=-1 measures (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional boolean field_id=-1 calculatePct;
#               optional group field_id=-1 classes (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional group field_id=-1 categories (List) {
#                       repeated group field_id=-1 list {
#                         optional group field_id=-1 element {
#                           optional group field_id=-1 measurements (List) {
#                             repeated group field_id=-1 list {
#                               optional group field_id=-1 element {
#                                 optional binary field_id=-1 comment (String);
#                                 optional binary field_id=-1 groupId (String);
#                                 optional binary field_id=-1 lowerLimit (String);
#                                 optional binary field_id=-1 spread (String);
#                                 optional binary field_id=-1 upperLimit (String);
#                                 optional binary field_id=-1 value (String);
#                               }
#                             }
#                           }
#                           optional binary field_id=-1 title (String);
#                         }
#                       }
#                     }
#                     optional group field_id=-1 denoms (List) {
#                       repeated group field_id=-1 list {
#                         optional group field_id=-1 element {
#                           optional group field_id=-1 counts (List) {
#                             repeated group field_id=-1 list {
#                               optional group field_id=-1 element {
#                                 optional binary field_id=-1 groupId (String);
#                                 optional binary field_id=-1 value (String);
#                               }
#                             }
#                           }
#                           optional binary field_id=-1 units (String);
#                         }
#                       }
#                     }
#                     optional binary field_id=-1 title (String);
#                   }
#                 }
#               }
#               optional binary field_id=-1 denomUnitsSelected (String);
#               optional group field_id=-1 denoms (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional group field_id=-1 counts (List) {
#                       repeated group field_id=-1 list {
#                         optional group field_id=-1 element {
#                           optional binary field_id=-1 groupId (String);
#                           optional binary field_id=-1 value (String);
#                         }
#                       }
#                     }
#                     optional binary field_id=-1 units (String);
#                   }
#                 }
#               }
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 dispersionType (String);
#               optional binary field_id=-1 paramType (String);
#               optional binary field_id=-1 populationDescription (String);
#               optional binary field_id=-1 title (String);
#               optional binary field_id=-1 unitOfMeasure (String);
#             }
#           }
#         }
#         optional binary field_id=-1 populationDescription (String);
#         optional binary field_id=-1 typeUnitsAnalyzed (String);
#       }
#       optional group field_id=-1 moreInfoModule {
#         optional group field_id=-1 certainAgreement {
#           optional binary field_id=-1 otherDetails (String);
#           optional boolean field_id=-1 piSponsorEmployee;
#           optional binary field_id=-1 restrictionType (String);
#           optional boolean field_id=-1 restrictiveAgreement;
#         }
#         optional group field_id=-1 limitationsAndCaveats {
#           optional binary field_id=-1 description (String);
#         }
#         optional group field_id=-1 pointOfContact {
#           optional binary field_id=-1 email (String);
#           optional binary field_id=-1 organization (String);
#           optional binary field_id=-1 phone (String);
#           optional binary field_id=-1 phoneExt (String);
#           optional binary field_id=-1 title (String);
#         }
#       }
#       optional group field_id=-1 outcomeMeasuresModule {
#         optional group field_id=-1 outcomeMeasures (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional group field_id=-1 analyses (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional binary field_id=-1 ciLowerLimit (String);
#                     optional binary field_id=-1 ciNumSides (String);
#                     optional binary field_id=-1 ciPctValue (String);
#                     optional binary field_id=-1 ciUpperLimit (String);
#                     optional binary field_id=-1 dispersionType (String);
#                     optional binary field_id=-1 dispersionValue (String);
#                     optional binary field_id=-1 estimateComment (String);
#                     optional binary field_id=-1 groupDescription (String);
#                     optional group field_id=-1 groupIds (List) {
#                       repeated group field_id=-1 list {
#                         optional binary field_id=-1 element (String);
#                       }
#                     }
#                     optional binary field_id=-1 nonInferiorityComment (String);
#                     optional binary field_id=-1 nonInferiorityType (String);
#                     optional binary field_id=-1 otherAnalysisDescription (String);
#                     optional binary field_id=-1 pValue (String);
#                     optional binary field_id=-1 pValueComment (String);
#                     optional binary field_id=-1 paramType (String);
#                     optional binary field_id=-1 paramValue (String);
#                     optional binary field_id=-1 statisticalComment (String);
#                     optional binary field_id=-1 statisticalMethod (String);
#                     optional boolean field_id=-1 testedNonInferiority;
#                   }
#                 }
#               }
#               optional binary field_id=-1 anticipatedPostingDate (String);
#               optional boolean field_id=-1 calculatePct;
#               optional group field_id=-1 classes (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional group field_id=-1 categories (List) {
#                       repeated group field_id=-1 list {
#                         optional group field_id=-1 element {
#                           optional group field_id=-1 measurements (List) {
#                             repeated group field_id=-1 list {
#                               optional group field_id=-1 element {
#                                 optional binary field_id=-1 comment (String);
#                                 optional binary field_id=-1 groupId (String);
#                                 optional binary field_id=-1 lowerLimit (String);
#                                 optional binary field_id=-1 spread (String);
#                                 optional binary field_id=-1 upperLimit (String);
#                                 optional binary field_id=-1 value (String);
#                               }
#                             }
#                           }
#                           optional binary field_id=-1 title (String);
#                         }
#                       }
#                     }
#                     optional group field_id=-1 denoms (List) {
#                       repeated group field_id=-1 list {
#                         optional group field_id=-1 element {
#                           optional group field_id=-1 counts (List) {
#                             repeated group field_id=-1 list {
#                               optional group field_id=-1 element {
#                                 optional binary field_id=-1 groupId (String);
#                                 optional binary field_id=-1 value (String);
#                               }
#                             }
#                           }
#                           optional binary field_id=-1 units (String);
#                         }
#                       }
#                     }
#                     optional binary field_id=-1 title (String);
#                   }
#                 }
#               }
#               optional binary field_id=-1 denomUnitsSelected (String);
#               optional group field_id=-1 denoms (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional group field_id=-1 counts (List) {
#                       repeated group field_id=-1 list {
#                         optional group field_id=-1 element {
#                           optional binary field_id=-1 groupId (String);
#                           optional binary field_id=-1 value (String);
#                         }
#                       }
#                     }
#                     optional binary field_id=-1 units (String);
#                   }
#                 }
#               }
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 dispersionType (String);
#               optional group field_id=-1 groups (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional binary field_id=-1 description (String);
#                     optional binary field_id=-1 id (String);
#                     optional binary field_id=-1 title (String);
#                   }
#                 }
#               }
#               optional binary field_id=-1 paramType (String);
#               optional binary field_id=-1 populationDescription (String);
#               optional binary field_id=-1 reportingStatus (String);
#               optional binary field_id=-1 timeFrame (String);
#               optional binary field_id=-1 title (String);
#               optional binary field_id=-1 type (String);
#               optional binary field_id=-1 typeUnitsAnalyzed (String);
#               optional binary field_id=-1 unitOfMeasure (String);
#             }
#           }
#         }
#       }
#       optional group field_id=-1 participantFlowModule {
#         optional group field_id=-1 groups (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional binary field_id=-1 description (String);
#               optional binary field_id=-1 id (String);
#               optional binary field_id=-1 title (String);
#             }
#           }
#         }
#         optional group field_id=-1 periods (List) {
#           repeated group field_id=-1 list {
#             optional group field_id=-1 element {
#               optional group field_id=-1 dropWithdraws (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional group field_id=-1 reasons (List) {
#                       repeated group field_id=-1 list {
#                         optional group field_id=-1 element {
#                           optional binary field_id=-1 groupId (String);
#                           optional binary field_id=-1 numSubjects (String);
#                         }
#                       }
#                     }
#                     optional binary field_id=-1 type (String);
#                   }
#                 }
#               }
#               optional group field_id=-1 milestones (List) {
#                 repeated group field_id=-1 list {
#                   optional group field_id=-1 element {
#                     optional group field_id=-1 achievements (List) {
#                       repeated group field_id=-1 list {
#                         optional group field_id=-1 element {
#                           optional binary field_id=-1 comment (String);
#                           optional binary field_id=-1 groupId (String);
#                           optional binary field_id=-1 numSubjects (String);
#                           optional binary field_id=-1 numUnits (String);
#                         }
#                       }
#                     }
#                     optional binary field_id=-1 comment (String);
#                     optional binary field_id=-1 type (String);
#                   }
#                 }
#               }
#               optional binary field_id=-1 title (String);
#             }
#           }
#         }
#         optional binary field_id=-1 preAssignmentDetails (String);
#         optional binary field_id=-1 recruitmentDetails (String);
#         optional binary field_id=-1 typeUnitsAnalyzed (String);
#       }
#     }
#   }
#   optional binary field_id=-1 nextPageToken (String);
# }

# %%
df_studies = pd.read_parquet("page1.parquet")

# %%
df_normalized = pd.json_normalize(df_studies['studies'])

# %%
# print(df_normalized)

# %%
study_df = pd.DataFrame({
    #identification
    'nct_id': df_normalized['protocolSection.identificationModule.nctId'],
    'title': df_normalized['protocolSection.identificationModule.officialTitle'],
    'acronym': df_normalized['protocolSection.identificationModule.acronym'],
    'organization_name': df_normalized['protocolSection.identificationModule.organization.fullName'],
    'organization_type': df_normalized['protocolSection.identificationModule.organization.class'],

    #sponsors and collaborators
    'sponsor_name': df_normalized['protocolSection.sponsorCollaboratorsModule.leadSponsor.name'],
    'sponsor_type': df_normalized['protocolSection.sponsorCollaboratorsModule.leadSponsor.class'],

    #description
    'brief_summary': df_normalized['protocolSection.descriptionModule.briefSummary'],
    'detailed_description': df_normalized['protocolSection.descriptionModule.detailedDescription'],

    #design
    'study_type': df_normalized['protocolSection.designModule.studyType'],
    'patient_registry': df_normalized['protocolSection.designModule.patientRegistry'],
    'target_duration': df_normalized['protocolSection.designModule.targetDuration'],
    'study_phase': df_normalized['protocolSection.designModule.targetDuration'],

    'design_allocation': df_normalized['protocolSection.designModule.designInfo.allocation'],
    'design_intervention_model': df_normalized['protocolSection.designModule.designInfo.interventionModel'],
    'design_intervention_model_desc': df_normalized['protocolSection.designModule.designInfo.interventionModelDescription'],

    'design_primary_purpose': df_normalized['protocolSection.designModule.designInfo.primaryPurpose'],
    'design_observational_model': df_normalized['protocolSection.designModule.designInfo.observationalModel'],
    'design_time_perspective': df_normalized['protocolSection.designModule.designInfo.timePerspective'],
    'design_masking': df_normalized['protocolSection.designModule.designInfo.maskingInfo.masking'],
    'design_masking_decsription': df_normalized['protocolSection.designModule.designInfo.maskingInfo.maskingDescription'],
    'design_who_masked': df_normalized['protocolSection.designModule.designInfo.maskingInfo.whoMasked'],

     #expanded access
    'exp_acc_type_intermediate': df_normalized['protocolSection.designModule.expandedAccessTypes.intermediate'],
    'exp_acc_type_treatment': df_normalized['protocolSection.designModule.expandedAccessTypes.treatment'],

    #Biospec
    'biospec_retention': df_normalized['protocolSection.designModule.bioSpec.retention'],
    'biospec_description': df_normalized['protocolSection.designModule.bioSpec.description'],

    #enrollment
    'enrollment_type': df_normalized['protocolSection.designModule.enrollmentInfo.type'],
    'enrollment_count': df_normalized['protocolSection.designModule.enrollmentInfo.count'],

    #arm group
    'arm_group_label': df_normalized['protocolSection.designModule.enrollmentInfo.type'],
    'arm_group_type': df_normalized['protocolSection.designModule.enrollmentInfo.count'],

     #eligibility
    'eligibility_criteria': df_normalized['protocolSection.eligibilityModule.eligibilityCriteria'],
    'healthy_volunteers': df_normalized['protocolSection.eligibilityModule.healthyVolunteers'],

    'sex': df_normalized['protocolSection.eligibilityModule.sex'],
    'gender_based': df_normalized['protocolSection.eligibilityModule.genderBased'],
    'gender_description': df_normalized['protocolSection.eligibilityModule.genderDescription'],
    'min_age': df_normalized['protocolSection.eligibilityModule.genderBased'],
    'max_age': df_normalized['protocolSection.eligibilityModule.sex'],
    'population_description': df_normalized['protocolSection.eligibilityModule.studyPopulation'],
    'sampling_method': df_normalized['protocolSection.eligibilityModule.samplingMethod'],

     #status
    'overall_status': df_normalized['protocolSection.statusModule.lastKnownStatus'],
    'last_known_status': df_normalized['protocolSection.statusModule.lastKnownStatus'],
    
    'start_date': df_normalized['protocolSection.statusModule.startDateStruct.date'],
    'start_date_type': df_normalized['protocolSection.statusModule.startDateStruct.type'],
    
    'first_submit_date': df_normalized['protocolSection.statusModule.studyFirstSubmitDate'],
    'first_submit_qc_date': df_normalized['protocolSection.statusModule.studyFirstSubmitQcDate'],
    
    'last_update_submit': df_normalized['protocolSection.statusModule.lastUpdateSubmitDate'],
    'completion_date': df_normalized['protocolSection.statusModule.completionDateStruct.date'],
    'completion_date_type': df_normalized['protocolSection.statusModule.completionDateStruct.type'],
    
    'why_stopped': df_normalized['protocolSection.statusModule.whyStopped'],
    'has_exp_access': df_normalized['protocolSection.statusModule.expandedAccessInfo.hasExpandedAccess'],

     #oversight
    'has_dmc': df_normalized['protocolSection.oversightModule.oversightHasDmc'],
    'is_fda_regulated_drug': df_normalized['protocolSection.oversightModule.isFdaRegulatedDrug'],
    'is_fda_regulated_device': df_normalized['protocolSection.oversightModule.isFdaRegulatedDevice'],
    'is_unapproved_device': df_normalized['protocolSection.oversightModule.isUnapprovedDevice'],
    # 'is_ppsd':df_normalized['protocolSection.oversightModule.isPpsd'],

    # individual participant data
    'ipd_sharing': df_normalized['protocolSection.ipdSharingStatementModule.ipdSharing'],
    'ipd_sharing_description': df_normalized['protocolSection.ipdSharingStatementModule.description'],
    'ipd_sharing_info_type': df_normalized['protocolSection.ipdSharingStatementModule.infoTypes'],
    'ipd_sharing_time_frame': df_normalized['protocolSection.ipdSharingStatementModule.timeFrame'],
    'ipd_sharing_access_criteria': df_normalized['protocolSection.ipdSharingStatementModule.accessCriteria'],
    'ipd_sharing_url': df_normalized['protocolSection.ipdSharingStatementModule.url'],

    # results
    'ipd_sharing': df_normalized['protocolSection.ipdSharingStatementModule.ipdSharing'],
    'ipd_sharing_description': df_normalized['protocolSection.ipdSharingStatementModule.description'],
    'ipd_sharing_info_type': df_normalized['protocolSection.ipdSharingStatementModule.infoTypes'],
    'ipd_sharing_time_frame': df_normalized['protocolSection.ipdSharingStatementModule.timeFrame'],


    # participant_flow
    'flow_pre_assignment_details': df_normalized['resultsSection.participantFlowModule.preAssignmentDetails'],
    'flow_recruitment_details': df_normalized['resultsSection.participantFlowModule.recruitmentDetails'],
    'flow_type_unit_analysed': df_normalized['resultsSection.participantFlowModule.typeUnitsAnalyzed'],

     # baseline characteristics
    'bsln_pop_desc': df_normalized['resultsSection.baselineCharacteristicsModule.populationDescription'],
    'bsln_pop_units_analysed': df_normalized['resultsSection.baselineCharacteristicsModule.typeUnitsAnalyzed'],

    # documents
    'large_doc_no_sap': df_normalized['documentSection.largeDocumentModule.noSap'],

    # Miscellaneous
    'version_holder': df_normalized['derivedSection.miscInfoModule.versionHolder'],
    'has_results': df_normalized['hasResults'],
   
    'last_updated': df_normalized['protocolSection.statusModule.lastUpdatePostDateStruct.date']
    

    

    
    
    #STUDY COLLABORATOR
    # 'collaborator_name': 'protocolSection.sponsorCollaboratorsModule.collaborators.name',
    # 'collaborator_type': 'protocolSection.sponsorCollaboratorsModule.collaborators.class',

    #STUDY CONDITIONS
    # 'condition': df_normalized['protocolSection.conditionsModule.conditions'],
    # 'keyword': df_normalized['protocolSection.conditionsModule.keywords'],

    
    #EXPANDED ACCESS INDIVIDUAL
    # 'exp_acc_type_individual': df_normalized['protocolSection.designModule.expandedAccessTypes.individual'],
    # 'exp_access_id':'protocolSection.statusModule.expandedAccessInfo.nctId',

    #STUDY ARM GROUP
    # 'arm_group_description': 'protocolSection.armsInterventionsModule.armGroups.description',
    # 'arm_group_intervention_names':'protocolSection.armsInterventionsModule.armGroups.interventionNames],

    #STUDY INTERVENTION
    # 'intervention_type': 'protocolSection.armsInterventionsModule.interventions.type',
    # 'intervention_name': 'protocolSection.armsInterventionsModule.interventions.name',
    # 'intervention_description':'protocolSection.armsInterventionsModule.interventions.description',
    # 'intervention_arm_group_labels':'protocolSection.armsInterventionsModule.interventions.armGroupLabels',

    #STUDY INTERVENTION OTHER NAMES
    # 'intervention_other_names':'protocolSection.armsInterventionsModule.interventions.otherNames',
    
    #PRIMARY STUDY OUTCOMES
    # 'primary_outcome_measure':'protocolSection.outcomesModule.primaryOutcomes.measure',
    # 'primary_outcome_description':'protocolSection.outcomesModule.primaryOutcomes.description',
    # 'primary_outcome_time_frame': 'protocolSection.outcomesModule.primaryOutcomes.timeFrame',

    #SECONDARY STUDY OUTCOMES
    # 'secondary_outcome_measure':'protocolSection.outcomesModule.secondaryOutcomes.measure',
    # 'secondary_outcome_description':'protocolSection.outcomesModule.secondaryOutcomes.description],
    # 'secondary_outcome_time_frame':'protocolSection.outcomesModule.secondaryOutcomes.timeFrame',

    #OTHER STUDY OUTCOMES
    # 'other_outcome_measure': df_normalized['protocolSection.outcomesModule.otherOutcomes.measure'],
    # 'other_outcome_description': df_normalized['protocolSection.outcomesModule.otherOutcomes.description'],
    # 'other_outcome_time_frame': df_normalized['protocolSection.outcomesModule.otherOutcomes.timeFrame'],

    #CENTRAL CONTACTS
    # 'central_contact_name':'protocolSection.contactsLocationsModule.centralContacts.name',
    # 'central_contact_role':'protocolSection.contactsLocationsModule.centralContacts.role',
    # 'central_contact_phone':'protocolSection.contactsLocationsModule.centralContacts.phone',
    # 'central_contact_phone_ext':'protocolSection.contactsLocationsModule.centralContacts.phoneExt',
    # 'central_contact_email':'protocolSection.contactsLocationsModule.centralContacts.email',

    #STUDY OFFICIALS
    # 'official_name':'protocolSection.contactsLocationsModule.overallOfficials.name',
    # 'official_role':'protocolSection.contactsLocationsModule.overallOfficials.role',
    # 'official_affiliation':'protocolSection.contactsLocationsModule.overallOfficials.affiliation',

    #STUDY SITES LOCATIONS
    # 'facility_name':'protocolSection.contactsLocationsModule.locations.facility',
    # 'facility_recruitment_status':'protocolSection.contactsLocationsModule.locations.status',
    # 'facility_city':'protocolSection.contactsLocationsModule.locations.city',
    # 'facility_state':'protocolSection.contactsLocationsModule.locations.state',
    # 'facility_zip':'protocolSection.contactsLocationsModule.locations.zip',
    # 'facility_country':'protocolSection.contactsLocationsModule.locations.country',


    #LOCATION CONTACTS
    # 'facility_contact_name':'protocolSection.contactsLocationsModule.locations.contacts.name',
    # 'facility_contact_role':'protocolSection.contactsLocationsModule.locations.contacts.role',
    # 'facility_contact_phone':'protocolSection.contactsLocationsModule.locations.contacts.phone',
    # 'facility_contact_phone_ext':'protocolSection.contactsLocationsModule.locations.contacts.phoneExt',
    # 'facility_contact_email':'protocolSection.contactsLocationsModule.locations.contacts.email',


    #REFERENCES
    # 'ref_pmid':'protocolSection.referencesModule.references.pmid',
    # 'ref_type':'protocolSection.referencesModule.references.type',
    # 'ref_citation':'protocolSection.referencesModule.references.citation',

    #RETRACTION
    # 'ret_pmid':'protocolSection.referencesModule.references.retractions.pmid',
    # 'ret_source':'protocolSection.referencesModule.references.retractions.status',

    #SEE ALSO LINK
    # 'see_also_label':'protocolSection.referencesModule.seeAlsoLinks.label',
    # 'see_also_url':'protocolSection.referencesModule.seeAlsoLinks.url',
    

    # PARTICIPANT FLOW GROUP----resultsSection.participantFlowModule.groups

    # 'fg_id':'resultsSection.participantFlowModule.groups.id',
    # 'fg_title': df_normalized['resultsSection.participantFlowModule.groups.title',
    # 'fg_description':'resultsSection.participantFlowModule.groups.description',

    
    # PARTICIPANT FLOW PERIOD----resultsSection.participantFlowModule.periods
    
    # 'fp_title':'resultsSection.participantFlowModule.periods.title',
    # 'fp_milestone':'resultsSection.participantFlowModule.periods.milestones',
    # 'fp_milestone_type':'resultsSection.participantFlowModule.periods.milestones.type',
    # 'fp_milestone_comment':'resultsSection.participantFlowModule.periods.milestones.comment',

        # FLOW PERIOD MILESTONE----resultsSection.participantFlowModule.periods.milestones.achievements
            # 'fa_group_id':'resultsSection.participantFlowModule.periods.milestones.achievements.groupId',
            # 'fa_group_comment':'resultsSection.participantFlowModule.periods.milestones.achievements.comment',
            # 'fa_group_num_participants':'resultsSection.participantFlowModule.periods.milestones.achievements.numSubjects',
            # 'fa_group_num_units': 'resultsSection.participantFlowModule.periods.milestones.achievements.numUnits',
    
    # FLOW DROP WITHDRAWS ---'resultsSection.participantFlowModule.periods.dropWithdraws',
        # 'fdw_type': 'resultsSection.participantFlowModule.periods.dropWithdraws.type',
        # 'fdw_comment': 'resultsSection.participantFlowModule.periods.dropWithdraws.comment',

        # 'FLOW DROP WITHDRAW REASONS ---'resultsSection.participantFlowModule.periods.dropWithdraws.reasons',
            # 'fdwr_group_id':'resultsSection.participantFlowModule.periods.dropWithdraws.reasons.groupId',
            # 'fdwr_group_comment': 'resultsSection.participantFlowModule.periods.dropWithdraws.comment'],
            # 'fdwr_group_num_subject': 'resultsSection.participantFlowModule.periods.dropWithdraws.reasons.numSubjects',

    # BASELINE CHARACTERISTICS --- df_normalized['resultsSection.baselineCharacteristicsModule.groups']
    
         #'bsln_group_id': df_normalized['resultsSection.baselineCharacteristicsModule.groups.id'],
         #'bsln_group_title': df_normalized['resultsSection.baselineCharacteristicsModule.groups.title'],
         #'bsln_group_desc': df_normalized['resultsSection.baselineCharacteristicsModule.groups.description'],
    
    # BASELINE DENOMS --- df_normalized['resultsSection.baselineCharacteristicsModule.denoms']
       #'bsln_denom_units': 'resultsSection.baselineCharacteristicsModule.denoms.units',
       #'bsln_denom_count': 'resultsSection.baselineCharacteristicsModule.denoms.counts',

    # BASELINE DENOMS COUNTS---'resultsSection.baselineCharacteristicsModule.denoms.counts'
        # 'bsln_denom_grp_id': 'resultsSection.baselineCharacteristicsModule.denoms.counts.groupId',
        # 'bsln_denom_group_count': 'resultsSection.baselineCharacteristicsModule.denoms.counts.value',

    # BASELINE MEASURES---df_normalized['resultsSection.baselineCharacteristicsModule.measures']
    
       # 'bsln_measures_title':'resultsSection.baselineCharacteristicsModule.measures.title',
       # 'bsln_measures_desc':'resultsSection.baselineCharacteristicsModule.measures.description',
       # 'bsln_measures_pop_desc': 'resultsSection.baselineCharacteristicsModule.measures.populationDescription',
       # 'bsln_measures_param_type': 'resultsSection.baselineCharacteristicsModule.measures.paramType',
       # 'bsln_dispersion_type': 'resultsSection.baselineCharacteristicsModule.measures.dispersionType',
       # 'bsln_measures_unit_of_meas': 'resultsSection.baselineCharacteristicsModule.measures.unitOfMeasure',
       # 'bsln_measures_calc_pct': 'resultsSection.baselineCharacteristicsModule.measures.calculatePct',
       # 'bsln_denom_units': 'resultsSection.baselineCharacteristicsModule.measures.denomUnitsSelected',

    # BASELINE MEASURES DENOMS---'resultsSection.baselineCharacteristicsModule.measures.denoms'
        # 'bsln_measure_denom_units': 'resultsSection.baselineCharacteristicsModule.measures.denoms.units',
        # 'bsln_measure_denom_counts':'resultsSection.baselineCharacteristicsModule.measures.denoms.counts',
    
    # BASELINE MEASURES DENOMS COUNTS---'resultsSection.baselineCharacteristicsModule.measures.denoms.counts'
        # 'bsln_measure_denom_counts_grp_id':'resultsSection.baselineCharacteristicsModule.measures.denoms.counts.groupId',
        # 'bsln_measure_denom_counts_value':'resultsSection.baselineCharacteristicsModule.measures.denoms.counts.value',

    # BASELINE MEASURES DENOMS CLASSES DENOMS---'resultsSection.baselineCharacteristicsModule.measures.classes',
     
        # 'bsln_class_title': 'resultsSection.baselineCharacteristicsModule.measures.classes.denoms',
        # 'bsln_class_denom_units':'resultsSection.baselineCharacteristicsModule.measures.classes.denoms.units',
        # 'bsln_class_denom_counts': 'resultsSection.baselineCharacteristicsModule.measures.classes.denoms.counts',


        # BASELINE MEASURES DENOMS CLASSES DENOMS COUNTS---'resultsSection.baselineCharacteristicsModule.measures.classes.counts',
            # 'bsln_class_denom_count_grp_id': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.denoms.counts.groupId'],
            # 'bsln_class_denom_count_value': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.denoms.counts.value'],


    # BASELINE MEASURES DENOMS CLASSES CATEGORIES---'resultsSection.baselineCharacteristicsModule.measures.classes.categories',
        # 'bsln_category_title': 'resultsSection.baselineCharacteristicsModule.measures.classes.categories.title',


        # BASELINE MEASURES DENOMS CLASSES CATEGORIES MEASUREMENTS---'resultsSection.baselineCharacteristicsModule.measures.classes.measurements',
            # 'bsln_meas_group_id': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurements.groupId'],
            # 'bsln_meas_value': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurements.value'],
            # 'bsln_meas_spread': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurements.spread'],
            # 'bsln_meas_value': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurements.value'],
            # 'bsln_meas_u_limit': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurements.upperLimit'],
            # 'bsln_meas_l_limit': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurements.lowerLimit'],
            # 'bsln_meas_comment': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurements.comment'],



    
    # OUTCOME MEASURES---df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures'],
  
        # 'om_type':'resultsSection.outcomeMeasuresModule.outcomeMeasures.type',
        # 'om_title':'resultsSection.outcomeMeasuresModule.outcomeMeasures.title',
        # 'om_description': 'resultsSection.outcomeMeasuresModule.outcomeMeasures.description',
        # 'om_pop_description':'resultsSection.outcomeMeasuresModule.outcomeMeasures.populationDescription',
        # 'om_reporting_status':'resultsSection.outcomeMeasuresModule.outcomeMeasures.reportingStatus',
        # 'om_anticipated_posting_date':'resultsSection.outcomeMeasuresModule.outcomeMeasures.anticipatedPostingDate',
        # 'om_param_type':'resultsSection.outcomeMeasuresModule.outcomeMeasures.paramType',
        # 'om_dispersion_type':'resultsSection.outcomeMeasuresModule.outcomeMeasures.dispersionType',
        # 'om_unit_of_measure':'resultsSection.outcomeMeasuresModule.outcomeMeasures.unitOfMeasure',
        # 'om_calc_pct':'resultsSection.outcomeMeasuresModule.outcomeMeasures.calculatePct',
        # 'om_time_frame':'resultsSection.outcomeMeasuresModule.outcomeMeasures.timeFrame',
        # 'om_type_units_analyzed':'resultsSection.outcomeMeasuresModule.outcomeMeasures.typeUnitsAnalyzed',
        # om_type':'resultsSection.outcomeMeasuresModule.outcomeMeasures.denomUnitsSelected',


        # OUTCOME MEASURE GROUPS---'resultsSection.outcomeMeasuresModule.outcomeMeasures.groups',
            # 'outcome_group_id':'resultsSection.outcomeMeasuresModule.outcomeMeasures.groups.id',
            # 'outcome_group_title':'resultsSection.outcomeMeasuresModule.outcomeMeasures.groups.title',
            # 'outcome_group_desc':'resultsSection.outcomeMeasuresModule.outcomeMeasures.groups.description',
            
        # denoms: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.groups'
            # 'outcome_denom_unit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.denoms.units'],
            # denom_counts: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.denoms.counts'
                # 'outcome_denom_count_group_id': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.denoms.counts.groupId'],
                # 'outcome_denom_count_group_value': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.denoms.counts.value'],

    # outcome class: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes'
    # 'outcome_class_title': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.title'],

        # outcome class denoms: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.denoms'
        # 'outcome_cls_denoms_unit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.denoms.units'],

            # outcome class denoms counts: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.denoms.counts'
                # 'outcome_cls_denom_count_group_id': df_normalized['	resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.denoms.counts.groupId'],
                # 'outcome_cls_denom_count_group_count_value': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.groups.value'],
    
    
    # outcome category: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories'
    # 'outcome_categories_title': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.categories.title'],

         # outcome category measurments: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements'
        # 'outcome_meas_group_id': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.value'],
        # 'outcome_meas_value': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.groupId'],
        # 'outcome_meas_spread': df_normalized['	resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.spread'],

        # 'outcome_meas_u_limit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.spread'],
        # 'outcome_meas_l_limit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.lowerLimit'],
        # 'outcome_meas_comment': df_normalized['	resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.comment'],

     # resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses
    #  'outcome_anlys_grp_id': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.groupIds'],
    #  'outcome_anlys_param_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.paramType'],
    #  'outcome_anlys_param_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.paramValue'],

    #  'outcome_anlys_dispersion_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.dispersionType'],
    #  'outcome_anlys_dispersion_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.dispersionValue'],
    #  'outcome_anlys_stat_method': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.statisticalMethod'],
    #  'outcome_anlys_stat_comment': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.statisticalComment'],
    #  'outcome_anlys_p_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.pValue'],
    #  'outcome_anlys_p_val_comment': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.pValueComment'],
    #  'outcome_anlys_ci_num_sides': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciNumSides'],
    #  'outcome_anlys_ci_pct_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciPctValue'],
    #  'outcome_anlys_ci_u_limit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciUpperLimit'],
    #  'outcome_anlys_ci_l_limit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciLowerLimit'],
    #  'outcome_anlys_ci_u_limit_cmt': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciUpperLimitComment'],
    #  'outcome_anlys_ci_l_limit_cmt': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciLowerLimitComment'],
    #  'outcome_anlys_estiate_cmt': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.estimateComment'],
    #  'outcome_anlys_tested_ni': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.testedNonInferiority'],
    #  'outcome_anlys_ni_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.nonInferiorityType'],
    #  'outcome_anlys_ni_cmt': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.nonInferiorityComment'],

    # 'outcome_anlys_other_anlys_desc': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.otherAnalysisDescription'],
    # 'outcome_anlys_other_anlys_grp_desc': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.groupDescription'],


   # resultsSection.adverseEventsModule
    # resultsSection.adverseEventsModule.frequencyThreshold
    # resultsSection.adverseEventsModule.timeFrame
    # resultsSection.adverseEventsModule.description
    # resultsSection.adverseEventsModule.allCauseMortalityComment
    # resultsSection.adverseEventsModule.eventGroups
        # resultsSection.adverseEventsModule.eventGroups.id
        # resultsSection.adverseEventsModule.eventGroups.title
        # resultsSection.adverseEventsModule.eventGroups.description
        # resultsSection.adverseEventsModule.eventGroups.deathsNumAffected
        # resultsSection.adverseEventsModule.eventGroups.deathsNumAtRisk
        # resultsSection.adverseEventsModule.eventGroups.seriousNumAffected
        # resultsSection.adverseEventsModule.eventGroups.seriousNumAtRisk
        # resultsSection.adverseEventsModule.eventGroups.otherNumAffected
        # resultsSection.adverseEventsModule.eventGroups.otherNumAtRisk

    # resultsSection.adverseEventsModule.seriousEvents
        # resultsSection.adverseEventsModule.seriousEvents.term
        # resultsSection.adverseEventsModule.seriousEvents.organSystem
        # resultsSection.adverseEventsModule.seriousEvents.sourceVocabulary
        # resultsSection.adverseEventsModule.seriousEvents.assessmentType
        # resultsSection.adverseEventsModule.seriousEvents.notes
    
        # resultsSection.adverseEventsModule.seriousEvents.stats
            # resultsSection.adverseEventsModule.seriousEvents.stats.groupId
            # resultsSection.adverseEventsModule.seriousEvents.stats.numEvents
            # resultsSection.adverseEventsModule.seriousEvents.stats.numAffected
            # resultsSection.adverseEventsModule.seriousEvents.stats.numAtRisk
    
    # resultsSection.adverseEventsModule.otherEvents
        # resultsSection.adverseEventsModule.otherEvents.term
        # resultsSection.adverseEventsModule.otherEvents.organSystem
        # resultsSection.adverseEventsModule.otherEvents.sourceVocabulary
        # resultsSection.adverseEventsModule.otherEvents.assessmentType
        # resultsSection.adverseEventsModule.otherEvents.notes
    
        # resultsSection.adverseEventsModule.otherEvents.stats
    
            # resultsSection.adverseEventsModule.otherEvents.stats.groupId
            # resultsSection.adverseEventsModule.otherEvents.stats.numEvents
            # resultsSection.adverseEventsModule.otherEvents.stats.numAffected
            # resultsSection.adverseEventsModule.otherEvents.stats.numAtRisk


    # resultsSection.moreInfoModule
    
    # resultsSection.moreInfoModule.limitationsAndCaveats
    #     resultsSection.moreInfoModule.limitationsAndCaveats.description

    # resultsSection.moreInfoModule.certainAgreement
        # resultsSection.moreInfoModule.certainAgreement.piSponsorEmployee
        # resultsSection.moreInfoModule.certainAgreement.restrictionType
        # resultsSection.moreInfoModule.certainAgreement.restrictiveAgreement
        # resultsSection.moreInfoModule.certainAgreement.otherDetails
    
    # resultsSection.moreInfoModule.pointOfContact
    #     resultsSection.moreInfoModule.pointOfContact.title
    #     resultsSection.moreInfoModule.pointOfContact.organization
    #     resultsSection.moreInfoModule.pointOfContact.email
    #     resultsSection.moreInfoModule.pointOfContact.phone
    #     resultsSection.moreInfoModule.pointOfContact.phoneExt


# annotationSection.annotationModule.unpostedAnnotation
#     annotationSection.annotationModule.unpostedAnnotation.unpostedResponsibleParty
#     annotationSection.annotationModule.unpostedAnnotation.unpostedEvents

#         annotationSection.annotationModule.unpostedAnnotation.unpostedEvents.type
#         annotationSection.annotationModule.unpostedAnnotation.unpostedEvents.date
#         annotationSection.annotationModule.unpostedAnnotation.unpostedEvents.dateUnknown
    
# annotationSection.annotationModule.violationAnnotation
#     annotationSection.annotationModule.violationAnnotation.violationEvents
    
#         annotationSection.annotationModule.violationAnnotation.violationEvents.type
#         annotationSection.annotationModule.violationAnnotation.violationEvents.description
#         annotationSection.annotationModule.violationAnnotation.violationEvents.creationDate
#         annotationSection.annotationModule.violationAnnotation.violationEvents.issuedDate
#         annotationSection.annotationModule.violationAnnotation.violationEvents.releaseDate
#         annotationSection.annotationModule.violationAnnotation.violationEvents.postedDate

# documentSection.largeDocumentModule.largeDocs
#     documentSection.largeDocumentModule.largeDocs.typeAbbrev
#     documentSection.largeDocumentModule.largeDocs.hasProtocol
#     documentSection.largeDocumentModule.largeDocs.hasSap
#     documentSection.largeDocumentModule.largeDocs.hasIcf
#     documentSection.largeDocumentModule.largeDocs.label
#     documentSection.largeDocumentModule.largeDocs.date
#     documentSection.largeDocumentModule.largeDocs.uploadDate
#     documentSection.largeDocumentModule.largeDocs.filename
#     documentSection.largeDocumentModule.largeDocs.size


# derivedSection.miscInfoModule.removedCountries

# derivedSection.miscInfoModule.submissionTracking
    # derivedSection.miscInfoModule.submissionTracking.estimatedResultsFirstSubmitDate
    # derivedSection.miscInfoModule.submissionTracking.firstMcpInfo
    #     derivedSection.miscInfoModule.submissionTracking.firstMcpInfo.postDateStruct
    #         derivedSection.miscInfoModule.submissionTracking.firstMcpInfo.postDateStruct.date
    #         derivedSection.miscInfoModule.submissionTracking.firstMcpInfo.postDateStruct.type
            
# derivedSection.miscInfoModule.submissionTracking.submissionInfos
#     derivedSection.miscInfoModule.submissionTracking.submissionInfos.releaseDate
#     derivedSection.miscInfoModule.submissionTracking.submissionInfos.unreleaseDate
#     derivedSection.miscInfoModule.submissionTracking.submissionInfos.unreleaseDateUnknown
#     derivedSection.miscInfoModule.submissionTracking.submissionInfos.resetDate
#     derivedSection.miscInfoModule.submissionTracking.submissionInfos.mcpReleaseN


# derivedSection.conditionBrowseModule.meshes
#     derivedSection.conditionBrowseModule.meshes.id
#     derivedSection.conditionBrowseModule.meshes.term
    
# derivedSection.conditionBrowseModule.ancestors
#     derivedSection.conditionBrowseModule.ancestors.id
#     derivedSection.conditionBrowseModule.ancestors.term

# derivedSection.conditionBrowseModule.browseLeaves
#     derivedSection.conditionBrowseModule.browseLeaves.id
#     derivedSection.conditionBrowseModule.browseLeaves.name
#     derivedSection.conditionBrowseModule.browseLeaves.asFound
#     derivedSection.conditionBrowseModule.browseLeaves.relevance
    
# derivedSection.conditionBrowseModule.browseBranches
#     derivedSection.conditionBrowseModule.browseBranches.abbrev
#     derivedSection.conditionBrowseModule.browseBranches.name

# derivedSection.interventionBrowseModule.meshes
#     derivedSection.interventionBrowseModule.meshes.id
#     derivedSection.interventionBrowseModule.meshes.term

# derivedSection.interventionBrowseModule.ancestors
#     derivedSection.interventionBrowseModule.ancestors.id
#     derivedSection.interventionBrowseModule.ancestors.term

# derivedSection.interventionBrowseModule.browseLeaves
#     derivedSection.interventionBrowseModule.browseLeaves.id
#     derivedSection.interventionBrowseModule.browseLeaves.name
#     derivedSection.interventionBrowseModule.browseLeaves.asFound
#     derivedSection.interventionBrowseModule.browseLeaves.relevance

# derivedSection.interventionBrowseModule.browseBranches
#     derivedSection.interventionBrowseModule.browseBranches.abbrev
#     derivedSection.interventionBrowseModule.browseBranches.name
                    
    
})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'protocolSection.oversightModule.isPpsd'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 88
#       1 study_df = pd.DataFrame({
#       2     #identification
#       3     'nct_id': df_normalized['protocolSection.identificationModule.nctId'],
#       4     'title': df_normalized['protocolSection.identificationModule.officialTitle'],
#       5     'acronym': df_normalized['protocolSection.identificationModule.acronym'],
#       6     'organization_name': df_normalized['protocolSection.identificationModule.organization.fullName'],
#       7     'organization_type': df_normalized['protocolSection.identificationModule.organization.class'],
#       8
#       9     #sponsors and collaborators
#      10     'sponsor_name': df_normalized['protocolSection.sponsorCollaboratorsModule.leadSponsor.name'],
#      11     'sponsor_type': df_normalized['protocolSection.sponsorCollaboratorsModule.leadSponsor.class'],
#      12
#      13     #description
#      14     'brief_summary': df_normalized['protocolSection.descriptionModule.briefSummary'],
#      15     'detailed_description': df_normalized['protocolSection.descriptionModule.detailedDescription'],
#      16
#      17     #conditions
#      18     'condition': df_normalized['protocolSection.conditionsModule.conditions'],
#      19     'keyword': df_normalized['protocolSection.conditionsModule.keywords'],
#      20
#      21     #design
#      22     'study_type': df_normalized['protocolSection.designModule.studyType'],
#      23     'patient_registry': df_normalized['protocolSection.designModule.patientRegistry'],
#      24     'target_duration': df_normalized['protocolSection.designModule.targetDuration'],
#      25     'study_phase': df_normalized['protocolSection.designModule.targetDuration'],
#      26
#      27     'design_allocation': df_normalized['protocolSection.designModule.designInfo.allocation'],
#      28     'design_intervention_model': df_normalized['protocolSection.designModule.designInfo.interventionModel'],
#      29     'design_intervention_model_desc': df_normalized['protocolSection.designModule.designInfo.interventionModelDescription'],
#      30
#      31     'design_primary_purpose': df_normalized['protocolSection.designModule.designInfo.primaryPurpose'],
#      32     'design_observational_model': df_normalized['protocolSection.designModule.designInfo.observationalModel'],
#      33     'design_time_perspective': df_normalized['protocolSection.designModule.designInfo.timePerspective'],
#      34     'design_masking': df_normalized['protocolSection.designModule.designInfo.maskingInfo.masking'],
#      35     'design_masking_decsription': df_normalized['protocolSection.designModule.designInfo.maskingInfo.maskingDescription'],
#      36     'design_who_masked': df_normalized['protocolSection.designModule.designInfo.maskingInfo.whoMasked'],
#      37
#      38      #expanded access
#      39     'exp_acc_type_intermediate': df_normalized['protocolSection.designModule.expandedAccessTypes.intermediate'],
#      40     'exp_acc_type_treatment': df_normalized['protocolSection.designModule.expandedAccessTypes.treatment'],
#      41
#      42     #Biospec
#      43     'biospec_retention': df_normalized['protocolSection.designModule.bioSpec.retention'],
#      44     'biospec_description': df_normalized['protocolSection.designModule.bioSpec.description'],
#      45
#      46     #enrollment
#      47     'enrollment_type': df_normalized['protocolSection.designModule.enrollmentInfo.type'],
#      48     'enrollment_count': df_normalized['protocolSection.designModule.enrollmentInfo.count'],
#      49
#      50     #arm group
#      51     'arm_group_label': df_normalized['protocolSection.designModule.enrollmentInfo.type'],
#      52     'arm_group_type': df_normalized['protocolSection.designModule.enrollmentInfo.count'],
#      53
#      54      #eligibility
#      55     'eligibility_criteria': df_normalized['protocolSection.eligibilityModule.eligibilityCriteria'],
#      56     'healthy_volunteers': df_normalized['protocolSection.eligibilityModule.healthyVolunteers'],
#      57
#      58     'sex': df_normalized['protocolSection.eligibilityModule.sex'],
#      59     'gender_based': df_normalized['protocolSection.eligibilityModule.genderBased'],
#      60     'gender_description': df_normalized['protocolSection.eligibilityModule.genderDescription'],
#      61     'min_age': df_normalized['protocolSection.eligibilityModule.genderBased'],
#      62     'max_age': df_normalized['protocolSection.eligibilityModule.sex'],
#      63     'population_description': df_normalized['protocolSection.eligibilityModule.studyPopulation'],
#      64     'sampling_method': df_normalized['protocolSection.eligibilityModule.samplingMethod'],
#      65
#      66      #status
#      67     'overall_status': df_normalized['protocolSection.statusModule.lastKnownStatus'],
#      68     'last_known_status': df_normalized['protocolSection.statusModule.lastKnownStatus'],
#      69
#      70     'start_date': df_normalized['protocolSection.statusModule.startDateStruct.date'],
#      71     'start_date_type': df_normalized['protocolSection.statusModule.startDateStruct.type'],
#      72
#      73     'first_submit_date': df_normalized['protocolSection.statusModule.studyFirstSubmitDate'],
#      74     'first_submit_qc_date': df_normalized['protocolSection.statusModule.studyFirstSubmitQcDate'],
#      75
#      76     'last_update_submit': df_normalized['protocolSection.statusModule.lastUpdateSubmitDate'],
#      77     'completion_date': df_normalized['protocolSection.statusModule.completionDateStruct.date'],
#      78     'completion_date_type': df_normalized['protocolSection.statusModule.completionDateStruct.type'],
#      79
#      80     'why_stopped': df_normalized['protocolSection.statusModule.whyStopped'],
#      81     'has_exp_access': df_normalized['protocolSection.statusModule.expandedAccessInfo.hasExpandedAccess'],
#      82
#      83      #oversight
#      84     'has_dmc': df_normalized['protocolSection.oversightModule.oversightHasDmc'],
#      85     'is_fda_regulated_drug': df_normalized['protocolSection.oversightModule.isFdaRegulatedDrug'],
#      86     'is_fda_regulated_device': df_normalized['protocolSection.oversightModule.isFdaRegulatedDevice'],
#      87     'is_unapproved_device': df_normalized['protocolSection.oversightModule.isUnapprovedDevice'],
# ---> 88     'is_ppsd':df_normalized['protocolSection.oversightModule.isPpsd'],
#      89
#      90     # individual participant data
#      91     'ipd_sharing': df_normalized['protocolSection.ipdSharingStatementModule.ipdSharing'],
#      92     'ipd_sharing_description': df_normalized['protocolSection.ipdSharingStatementModule.description'],
#      93     'ipd_sharing_info_type': df_normalized['protocolSection.ipdSharingStatementModule.infoTypes'],
#      94     'ipd_sharing_time_frame': df_normalized['protocolSection.ipdSharingStatementModule.timeFrame'],
#      95     'ipd_sharing_access_criteria': df_normalized['protocolSection.ipdSharingStatementModule.accessCriteria'],
#      96     'ipd_sharing_url': df_normalized['protocolSection.ipdSharingStatementModule.url'],
#      97
#      98     # results
#      99     'ipd_sharing': df_normalized['protocolSection.ipdSharingStatementModule.ipdSharing'],
#     100     'ipd_sharing_description': df_normalized['protocolSection.ipdSharingStatementModule.description'],
#     101     'ipd_sharing_info_type': df_normalized['protocolSection.ipdSharingStatementModule.infoTypes'],
#     102     'ipd_sharing_time_frame': df_normalized['protocolSection.ipdSharingStatementModule.timeFrame'],
#     103
#     104
#     105     # participant_flow
#     106     'flow_pre_assignment_details': df_normalized['resultsSection.participantFlowModule.preAssignmentDetails'],
#     107     'flow_recruitment_details': df_normalized['resultsSection.participantFlowModule.recruitmentDetails'],
#     108     'flow_type_unit_analysed': df_normalized['resultsSection.participantFlowModule.typeUnitsAnalyzed'],
#     109
#     110      # baseline characteristics
#     111     'bsln_pop_desc': df_normalized['resultsSection.baselineCharacteristicsModule.populationDescription'],
#     112     'bsln_pop_units_analysed': df_normalized['resultsSection.baselineCharacteristicsModule.typeUnitsAnalyzed'],
#     113
#     114     # documents
#     115     'large_doc_no_sap': df_normalized['documentSection.largeDocumentModule.noSap'],
#     116
#     117     # Miscellaneous
#     118     'version_holder': df_normalized['derivedSection.miscInfoModule.versionHolder'],
#     119     'has_results': df_normalized['hasResults'],
#     120
#     121     'last_updated': df_normalized['protocolSection.statusModule.lastUpdatePostDateStruct.date']
#     122
#     123
#     124
#     125
#     126
#     127
#     128     #STUDY COLLABORATOR
#     129     # 'collaborator_name': 'protocolSection.sponsorCollaboratorsModule.collaborators.name',
#     130     # 'collaborator_type': 'protocolSection.sponsorCollaboratorsModule.collaborators.class',
#     131
#     132     #EXPANDED ACCESS INDIVIDUAL
#     133     # 'exp_acc_type_individual': df_normalized['protocolSection.designModule.expandedAccessTypes.individual'],
#     134     # 'exp_access_id':'protocolSection.statusModule.expandedAccessInfo.nctId',
#     135
#     136     #STUDY ARM GROUP
#     137     # 'arm_group_description': 'protocolSection.armsInterventionsModule.armGroups.description',
#     138     # 'arm_group_intervention_names':'protocolSection.armsInterventionsModule.armGroups.interventionNames],
#     139
#     140     #STUDY INTERVENTION
#     141     # 'intervention_type': 'protocolSection.armsInterventionsModule.interventions.type',
#     142     # 'intervention_name': 'protocolSection.armsInterventionsModule.interventions.name',
#     143     # 'intervention_description':'protocolSection.armsInterventionsModule.interventions.description',
#     144     # 'intervention_arm_group_labels':'protocolSection.armsInterventionsModule.interventions.armGroupLabels',
#     145
#     146     #STUDY INTERVENTION OTHER NAMES
#     147     # 'intervention_other_names':'protocolSection.armsInterventionsModule.interventions.otherNames',
#     148
#     149     #PRIMARY STUDY OUTCOMES
#     150     # 'primary_outcome_measure':'protocolSection.outcomesModule.primaryOutcomes.measure',
#     151     # 'primary_outcome_description':'protocolSection.outcomesModule.primaryOutcomes.description',
#     152     # 'primary_outcome_time_frame': 'protocolSection.outcomesModule.primaryOutcomes.timeFrame',
#     153
#     154     #SECONDARY STUDY OUTCOMES
#     155     # 'secondary_outcome_measure':'protocolSection.outcomesModule.secondaryOutcomes.measure',
#     156     # 'secondary_outcome_description':'protocolSection.outcomesModule.secondaryOutcomes.description],
#     157     # 'secondary_outcome_time_frame':'protocolSection.outcomesModule.secondaryOutcomes.timeFrame',
#     158
#     159     #OTHER STUDY OUTCOMES
#     160     # 'other_outcome_measure': df_normalized['protocolSection.outcomesModule.otherOutcomes.measure'],
#     161     # 'other_outcome_description': df_normalized['protocolSection.outcomesModule.otherOutcomes.description'],
#     162     # 'other_outcome_time_frame': df_normalized['protocolSection.outcomesModule.otherOutcomes.timeFrame'],
#     163
#     164     #CENTRAL CONTACTS
#     165     # 'central_contact_name':'protocolSection.contactsLocationsModule.centralContacts.name',
#     166     # 'central_contact_role':'protocolSection.contactsLocationsModule.centralContacts.role',
#     167     # 'central_contact_phone':'protocolSection.contactsLocationsModule.centralContacts.phone',
#     168     # 'central_contact_phone_ext':'protocolSection.contactsLocationsModule.centralContacts.phoneExt',
#     169     # 'central_contact_email':'protocolSection.contactsLocationsModule.centralContacts.email',
#     170
#     171     #STUDY OFFICIALS
#     172     # 'official_name':'protocolSection.contactsLocationsModule.overallOfficials.name',
#     173     # 'official_role':'protocolSection.contactsLocationsModule.overallOfficials.role',
#     174     # 'official_affiliation':'protocolSection.contactsLocationsModule.overallOfficials.affiliation',
#     175
#     176     #STUDY SITES LOCATIONS
#     177     # 'facility_name':'protocolSection.contactsLocationsModule.locations.facility',
#     178     # 'facility_recruitment_status':'protocolSection.contactsLocationsModule.locations.status',
#     179     # 'facility_city':'protocolSection.contactsLocationsModule.locations.city',
#     180     # 'facility_state':'protocolSection.contactsLocationsModule.locations.state',
#     181     # 'facility_zip':'protocolSection.contactsLocationsModule.locations.zip',
#     182     # 'facility_country':'protocolSection.contactsLocationsModule.locations.country',
#     183
#     184
#     185     #LOCATION CONTACTS
#     186     # 'facility_contact_name':'protocolSection.contactsLocationsModule.locations.contacts.name',
#     187     # 'facility_contact_role':'protocolSection.contactsLocationsModule.locations.contacts.role',
#     188     # 'facility_contact_phone':'protocolSection.contactsLocationsModule.locations.contacts.phone',
#     189     # 'facility_contact_phone_ext':'protocolSection.contactsLocationsModule.locations.contacts.phoneExt',
#     190     # 'facility_contact_email':'protocolSection.contactsLocationsModule.locations.contacts.email',
#     191
#     192
#     193     #REFERENCES
#     194     # 'ref_pmid':'protocolSection.referencesModule.references.pmid',
#     195     # 'ref_type':'protocolSection.referencesModule.references.type',
#     196     # 'ref_citation':'protocolSection.referencesModule.references.citation',
#     197
#     198     #RETRACTION
#     199     # 'ret_pmid':'protocolSection.referencesModule.references.retractions.pmid',
#     200     # 'ret_source':'protocolSection.referencesModule.references.retractions.status',
#     201
#     202     #SEE ALSO LINK
#     203     # 'see_also_label':'protocolSection.referencesModule.seeAlsoLinks.label',
#     204     # 'see_also_url':'protocolSection.referencesModule.seeAlsoLinks.url',
#     205
#     206
#     207     # PARTICIPANT FLOW GROUP----resultsSection.participantFlowModule.groups
#     208
#     209     # 'fg_id':'resultsSection.participantFlowModule.groups.id',
#     210     # 'fg_title': df_normalized['resultsSection.participantFlowModule.groups.title',
#     211     # 'fg_description':'resultsSection.participantFlowModule.groups.description',
#     212
#     213
#     214     # PARTICIPANT FLOW PERIOD----resultsSection.participantFlowModule.periods
#     215
#     216     # 'fp_title':'resultsSection.participantFlowModule.periods.title',
#     217     # 'fp_milestone':'resultsSection.participantFlowModule.periods.milestones',
#     218     # 'fp_milestone_type':'resultsSection.participantFlowModule.periods.milestones.type',
#     219     # 'fp_milestone_comment':'resultsSection.participantFlowModule.periods.milestones.comment',
#     220
#     221         # FLOW PERIOD MILESTONE----resultsSection.participantFlowModule.periods.milestones.achievements
#     222             # 'fa_group_id':'resultsSection.participantFlowModule.periods.milestones.achievements.groupId',
#     223             # 'fa_group_comment':'resultsSection.participantFlowModule.periods.milestones.achievements.comment',
#     224             # 'fa_group_num_participants':'resultsSection.participantFlowModule.periods.milestones.achievements.numSubjects',
#     225             # 'fa_group_num_units': 'resultsSection.participantFlowModule.periods.milestones.achievements.numUnits',
#     226
#     227     # FLOW DROP WITHDRAWS ---'resultsSection.participantFlowModule.periods.dropWithdraws',
#     228         # 'fdw_type': 'resultsSection.participantFlowModule.periods.dropWithdraws.type',
#     229         # 'fdw_comment': 'resultsSection.participantFlowModule.periods.dropWithdraws.comment',
#     230
#     231         # 'FLOW DROP WITHDRAW REASONS ---'resultsSection.participantFlowModule.periods.dropWithdraws.reasons',
#     232             # 'fdwr_group_id':'resultsSection.participantFlowModule.periods.dropWithdraws.reasons.groupId',
#     233             # 'fdwr_group_comment': 'resultsSection.participantFlowModule.periods.dropWithdraws.comment'],
#     234             # 'fdwr_group_num_subject': 'resultsSection.participantFlowModule.periods.dropWithdraws.reasons.numSubjects',
#     235
#     236     # BASELINE CHARACTERISTICS --- df_normalized['resultsSection.baselineCharacteristicsModule.groups']
#     237
#     238          #'bsln_group_id': df_normalized['resultsSection.baselineCharacteristicsModule.groups.id'],
#     239          #'bsln_group_title': df_normalized['resultsSection.baselineCharacteristicsModule.groups.title'],
#     240          #'bsln_group_desc': df_normalized['resultsSection.baselineCharacteristicsModule.groups.description'],
#     241
#     242     # BASELINE DENOMS --- df_normalized['resultsSection.baselineCharacteristicsModule.denoms']
#     243        #'bsln_denom_units': 'resultsSection.baselineCharacteristicsModule.denoms.units',
#     244        #'bsln_denom_count': 'resultsSection.baselineCharacteristicsModule.denoms.counts',
#     245
#     246     # BASELINE DENOMS COUNTS---'resultsSection.baselineCharacteristicsModule.denoms.counts'
#     247         # 'bsln_denom_grp_id': 'resultsSection.baselineCharacteristicsModule.denoms.counts.groupId',
#     248         # 'bsln_denom_group_count': 'resultsSection.baselineCharacteristicsModule.denoms.counts.value',
#     249
#     250     # BASELINE MEASURES---df_normalized['resultsSection.baselineCharacteristicsModule.measures']
#     251
#     252        # 'bsln_measures_title':'resultsSection.baselineCharacteristicsModule.measures.title',
#     253        # 'bsln_measures_desc':'resultsSection.baselineCharacteristicsModule.measures.description',
#     254        # 'bsln_measures_pop_desc': 'resultsSection.baselineCharacteristicsModule.measures.populationDescription',
#     255        # 'bsln_measures_param_type': 'resultsSection.baselineCharacteristicsModule.measures.paramType',
#     256        # 'bsln_dispersion_type': 'resultsSection.baselineCharacteristicsModule.measures.dispersionType',
#     257        # 'bsln_measures_unit_of_meas': 'resultsSection.baselineCharacteristicsModule.measures.unitOfMeasure',
#     258        # 'bsln_measures_calc_pct': 'resultsSection.baselineCharacteristicsModule.measures.calculatePct',
#     259        # 'bsln_denom_units': 'resultsSection.baselineCharacteristicsModule.measures.denomUnitsSelected',
#     260
#     261     # BASELINE MEASURES DENOMS---'resultsSection.baselineCharacteristicsModule.measures.denoms'
#     262         # 'bsln_measure_denom_units': 'resultsSection.baselineCharacteristicsModule.measures.denoms.units',
#     263         # 'bsln_measure_denom_counts':'resultsSection.baselineCharacteristicsModule.measures.denoms.counts',
#     264
#     265     # BASELINE MEASURES DENOMS COUNTS---'resultsSection.baselineCharacteristicsModule.measures.denoms.counts'
#     266         # 'bsln_measure_denom_counts_grp_id':'resultsSection.baselineCharacteristicsModule.measures.denoms.counts.groupId',
#     267         # 'bsln_measure_denom_counts_value':'resultsSection.baselineCharacteristicsModule.measures.denoms.counts.value',
#     268
#     269     # BASELINE MEASURES DENOMS CLASSES DENOMS---'resultsSection.baselineCharacteristicsModule.measures.classes',
#     270
#     271         # 'bsln_class_title': 'resultsSection.baselineCharacteristicsModule.measures.classes.denoms',
#     272         # 'bsln_class_denom_units':'resultsSection.baselineCharacteristicsModule.measures.classes.denoms.units',
#     273         # 'bsln_class_denom_counts': 'resultsSection.baselineCharacteristicsModule.measures.classes.denoms.counts',
#     274
#     275
#     276         # BASELINE MEASURES DENOMS CLASSES DENOMS COUNTS---'resultsSection.baselineCharacteristicsModule.measures.classes.counts',
#     277             # 'bsln_class_denom_count_grp_id': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.denoms.counts.groupId'],
#     278             # 'bsln_class_denom_count_value': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.denoms.counts.value'],
#     279
#     280
#     281     # BASELINE MEASURES DENOMS CLASSES CATEGORIES---'resultsSection.baselineCharacteristicsModule.measures.classes.categories',
#     282         # 'bsln_category_title': 'resultsSection.baselineCharacteristicsModule.measures.classes.categories.title',
#     283
#     284
#     285         # BASELINE MEASURES DENOMS CLASSES CATEGORIES MEASUREMENTS---'resultsSection.baselineCharacteristicsModule.measures.classes.measurements',
#     286             # 'bsln_meas_group_id': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurements.groupId'],
#     287             # 'bsln_meas_value': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurements.value'],
#     288             # 'bsln_meas_spread': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurements.spread'],
#     289             # 'bsln_meas_value': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurements.value'],
#     290             # 'bsln_meas_u_limit': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurements.upperLimit'],
#     291             # 'bsln_meas_l_limit': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurements.lowerLimit'],
#     292             # 'bsln_meas_comment': df_normalized['resultsSection.baselineCharacteristicsModule.measures.classes.categories.measurements.comment'],
#     293
#     294
#     295
#     296
#     297     # OUTCOME MEASURES---df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures'],
#     298
#     299         # 'om_type':'resultsSection.outcomeMeasuresModule.outcomeMeasures.type',
#     300         # 'om_title':'resultsSection.outcomeMeasuresModule.outcomeMeasures.title',
#     301         # 'om_description': 'resultsSection.outcomeMeasuresModule.outcomeMeasures.description',
#     302         # 'om_pop_description':'resultsSection.outcomeMeasuresModule.outcomeMeasures.populationDescription',
#     303         # 'om_reporting_status':'resultsSection.outcomeMeasuresModule.outcomeMeasures.reportingStatus',
#     304         # 'om_anticipated_posting_date':'resultsSection.outcomeMeasuresModule.outcomeMeasures.anticipatedPostingDate',
#     305         # 'om_param_type':'resultsSection.outcomeMeasuresModule.outcomeMeasures.paramType',
#     306         # 'om_dispersion_type':'resultsSection.outcomeMeasuresModule.outcomeMeasures.dispersionType',
#     307         # 'om_unit_of_measure':'resultsSection.outcomeMeasuresModule.outcomeMeasures.unitOfMeasure',
#     308         # 'om_calc_pct':'resultsSection.outcomeMeasuresModule.outcomeMeasures.calculatePct',
#     309         # 'om_time_frame':'resultsSection.outcomeMeasuresModule.outcomeMeasures.timeFrame',
#     310         # 'om_type_units_analyzed':'resultsSection.outcomeMeasuresModule.outcomeMeasures.typeUnitsAnalyzed',
#     311         # om_type':'resultsSection.outcomeMeasuresModule.outcomeMeasures.denomUnitsSelected',
#     312
#     313
#     314         # OUTCOME MEASURE GROUPS---'resultsSection.outcomeMeasuresModule.outcomeMeasures.groups',
#     315             # 'outcome_group_id':'resultsSection.outcomeMeasuresModule.outcomeMeasures.groups.id',
#     316             # 'outcome_group_title':'resultsSection.outcomeMeasuresModule.outcomeMeasures.groups.title',
#     317             # 'outcome_group_desc':'resultsSection.outcomeMeasuresModule.outcomeMeasures.groups.description',
#     318
#     319         # denoms: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.groups'
#     320             # 'outcome_denom_unit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.denoms.units'],
#     321             # denom_counts: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.denoms.counts'
#     322                 # 'outcome_denom_count_group_id': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.denoms.counts.groupId'],
#     323                 # 'outcome_denom_count_group_value': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.denoms.counts.value'],
#     324
#     325     # outcome class: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes'
#     326     # 'outcome_class_title': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.title'],
#     327
#     328         # outcome class denoms: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.denoms'
#     329         # 'outcome_cls_denoms_unit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.denoms.units'],
#     330
#     331             # outcome class denoms counts: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.denoms.counts'
#     332                 # 'outcome_cls_denom_count_group_id': df_normalized['	resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.denoms.counts.groupId'],
#     333                 # 'outcome_cls_denom_count_group_count_value': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.groups.value'],
#     334
#     335
#     336     # outcome category: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories'
#     337     # 'outcome_categories_title': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.categories.title'],
#     338
#     339          # outcome category measurments: 'resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements'
#     340         # 'outcome_meas_group_id': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.value'],
#     341         # 'outcome_meas_value': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.groupId'],
#     342         # 'outcome_meas_spread': df_normalized['	resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.spread'],
#     343
#     344         # 'outcome_meas_u_limit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.spread'],
#     345         # 'outcome_meas_l_limit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.lowerLimit'],
#     346         # 'outcome_meas_comment': df_normalized['	resultsSection.outcomeMeasuresModule.outcomeMeasures.classes.categories.measurements.comment'],
#     347
#     348      # resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses
#     349     #  'outcome_anlys_grp_id': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.groupIds'],
#     350     #  'outcome_anlys_param_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.paramType'],
#     351     #  'outcome_anlys_param_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.paramValue'],
#     352
#     353     #  'outcome_anlys_dispersion_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.dispersionType'],
#     354     #  'outcome_anlys_dispersion_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.dispersionValue'],
#     355     #  'outcome_anlys_stat_method': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.statisticalMethod'],
#     356     #  'outcome_anlys_stat_comment': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.statisticalComment'],
#     357     #  'outcome_anlys_p_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.pValue'],
#     358     #  'outcome_anlys_p_val_comment': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.pValueComment'],
#     359     #  'outcome_anlys_ci_num_sides': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciNumSides'],
#     360     #  'outcome_anlys_ci_pct_val': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciPctValue'],
#     361     #  'outcome_anlys_ci_u_limit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciUpperLimit'],
#     362     #  'outcome_anlys_ci_l_limit': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciLowerLimit'],
#     363     #  'outcome_anlys_ci_u_limit_cmt': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciUpperLimitComment'],
#     364     #  'outcome_anlys_ci_l_limit_cmt': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.ciLowerLimitComment'],
#     365     #  'outcome_anlys_estiate_cmt': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.estimateComment'],
#     366     #  'outcome_anlys_tested_ni': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.testedNonInferiority'],
#     367     #  'outcome_anlys_ni_type': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.nonInferiorityType'],
#     368     #  'outcome_anlys_ni_cmt': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.nonInferiorityComment'],
#     369
#     370     # 'outcome_anlys_other_anlys_desc': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.otherAnalysisDescription'],
#     371     # 'outcome_anlys_other_anlys_grp_desc': df_normalized['resultsSection.outcomeMeasuresModule.outcomeMeasures.analyses.groupDescription'],
#     372
#     373
#     374    # resultsSection.adverseEventsModule
#     375     # resultsSection.adverseEventsModule.frequencyThreshold
#     376     # resultsSection.adverseEventsModule.timeFrame
#     377     # resultsSection.adverseEventsModule.description
#     378     # resultsSection.adverseEventsModule.allCauseMortalityComment
#     379     # resultsSection.adverseEventsModule.eventGroups
#     380         # resultsSection.adverseEventsModule.eventGroups.id
#     381         # resultsSection.adverseEventsModule.eventGroups.title
#     382         # resultsSection.adverseEventsModule.eventGroups.description
#     383         # resultsSection.adverseEventsModule.eventGroups.deathsNumAffected
#     384         # resultsSection.adverseEventsModule.eventGroups.deathsNumAtRisk
#     385         # resultsSection.adverseEventsModule.eventGroups.seriousNumAffected
#     386         # resultsSection.adverseEventsModule.eventGroups.seriousNumAtRisk
#     387         # resultsSection.adverseEventsModule.eventGroups.otherNumAffected
#     388         # resultsSection.adverseEventsModule.eventGroups.otherNumAtRisk
#     389
#     390     # resultsSection.adverseEventsModule.seriousEvents
#     391         # resultsSection.adverseEventsModule.seriousEvents.term
#     392         # resultsSection.adverseEventsModule.seriousEvents.organSystem
#     393         # resultsSection.adverseEventsModule.seriousEvents.sourceVocabulary
#     394         # resultsSection.adverseEventsModule.seriousEvents.assessmentType
#     395         # resultsSection.adverseEventsModule.seriousEvents.notes
#     396
#     397         # resultsSection.adverseEventsModule.seriousEvents.stats
#     398             # resultsSection.adverseEventsModule.seriousEvents.stats.groupId
#     399             # resultsSection.adverseEventsModule.seriousEvents.stats.numEvents
#     400             # resultsSection.adverseEventsModule.seriousEvents.stats.numAffected
#     401             # resultsSection.adverseEventsModule.seriousEvents.stats.numAtRisk
#     402
#     403     # resultsSection.adverseEventsModule.otherEvents
#     404         # resultsSection.adverseEventsModule.otherEvents.term
#     405         # resultsSection.adverseEventsModule.otherEvents.organSystem
#     406         # resultsSection.adverseEventsModule.otherEvents.sourceVocabulary
#     407         # resultsSection.adverseEventsModule.otherEvents.assessmentType
#     408         # resultsSection.adverseEventsModule.otherEvents.notes
#     409
#     410         # resultsSection.adverseEventsModule.otherEvents.stats
#     411
#     412             # resultsSection.adverseEventsModule.otherEvents.stats.groupId
#     413             # resultsSection.adverseEventsModule.otherEvents.stats.numEvents
#     414             # resultsSection.adverseEventsModule.otherEvents.stats.numAffected
#     415             # resultsSection.adverseEventsModule.otherEvents.stats.numAtRisk
#     416
#     417
#     418     # resultsSection.moreInfoModule
#     419
#     420     # resultsSection.moreInfoModule.limitationsAndCaveats
#     421     #     resultsSection.moreInfoModule.limitationsAndCaveats.description
#     422
#     423     # resultsSection.moreInfoModule.certainAgreement
#     424         # resultsSection.moreInfoModule.certainAgreement.piSponsorEmployee
#     425         # resultsSection.moreInfoModule.certainAgreement.restrictionType
#     426         # resultsSection.moreInfoModule.certainAgreement.restrictiveAgreement
#     427         # resultsSection.moreInfoModule.certainAgreement.otherDetails
#     428
#     429     # resultsSection.moreInfoModule.pointOfContact
#     430     #     resultsSection.moreInfoModule.pointOfContact.title
#     431     #     resultsSection.moreInfoModule.pointOfContact.organization
#     432     #     resultsSection.moreInfoModule.pointOfContact.email
#     433     #     resultsSection.moreInfoModule.pointOfContact.phone
#     434     #     resultsSection.moreInfoModule.pointOfContact.phoneExt
#     435
#     436
#     437 # annotationSection.annotationModule.unpostedAnnotation
#     438 #     annotationSection.annotationModule.unpostedAnnotation.unpostedResponsibleParty
#     439 #     annotationSection.annotationModule.unpostedAnnotation.unpostedEvents
#     440
#     441 #         annotationSection.annotationModule.unpostedAnnotation.unpostedEvents.type
#     442 #         annotationSection.annotationModule.unpostedAnnotation.unpostedEvents.date
#     443 #         annotationSection.annotationModule.unpostedAnnotation.unpostedEvents.dateUnknown
#     444
#     445 # annotationSection.annotationModule.violationAnnotation
#     446 #     annotationSection.annotationModule.violationAnnotation.violationEvents
#     447
#     448 #         annotationSection.annotationModule.violationAnnotation.violationEvents.type
#     449 #         annotationSection.annotationModule.violationAnnotation.violationEvents.description
#     450 #         annotationSection.annotationModule.violationAnnotation.violationEvents.creationDate
#     451 #         annotationSection.annotationModule.violationAnnotation.violationEvents.issuedDate
#     452 #         annotationSection.annotationModule.violationAnnotation.violationEvents.releaseDate
#     453 #         annotationSection.annotationModule.violationAnnotation.violationEvents.postedDate
#     454
#     455 # documentSection.largeDocumentModule.largeDocs
#     456 #     documentSection.largeDocumentModule.largeDocs.typeAbbrev
#     457 #     documentSection.largeDocumentModule.largeDocs.hasProtocol
#     458 #     documentSection.largeDocumentModule.largeDocs.hasSap
#     459 #     documentSection.largeDocumentModule.largeDocs.hasIcf
#     460 #     documentSection.largeDocumentModule.largeDocs.label
#     461 #     documentSection.largeDocumentModule.largeDocs.date
#     462 #     documentSection.largeDocumentModule.largeDocs.uploadDate
#     463 #     documentSection.largeDocumentModule.largeDocs.filename
#     464 #     documentSection.largeDocumentModule.largeDocs.size
#     465
#     466
#     467 # derivedSection.miscInfoModule.removedCountries
#     468
#     469 # derivedSection.miscInfoModule.submissionTracking
#     470     # derivedSection.miscInfoModule.submissionTracking.estimatedResultsFirstSubmitDate
#     471     # derivedSection.miscInfoModule.submissionTracking.firstMcpInfo
#     472     #     derivedSection.miscInfoModule.submissionTracking.firstMcpInfo.postDateStruct
#     473     #         derivedSection.miscInfoModule.submissionTracking.firstMcpInfo.postDateStruct.date
#     474     #         derivedSection.miscInfoModule.submissionTracking.firstMcpInfo.postDateStruct.type
#     475
#     476 # derivedSection.miscInfoModule.submissionTracking.submissionInfos
#     477 #     derivedSection.miscInfoModule.submissionTracking.submissionInfos.releaseDate
#     478 #     derivedSection.miscInfoModule.submissionTracking.submissionInfos.unreleaseDate
#     479 #     derivedSection.miscInfoModule.submissionTracking.submissionInfos.unreleaseDateUnknown
#     480 #     derivedSection.miscInfoModule.submissionTracking.submissionInfos.resetDate
#     481 #     derivedSection.miscInfoModule.submissionTracking.submissionInfos.mcpReleaseN
#     482
#     483
#     484 # derivedSection.conditionBrowseModule.meshes
#     485 #     derivedSection.conditionBrowseModule.meshes.id
#     486 #     derivedSection.conditionBrowseModule.meshes.term
#     487
#     488 # derivedSection.conditionBrowseModule.ancestors
#     489 #     derivedSection.conditionBrowseModule.ancestors.id
#     490 #     derivedSection.conditionBrowseModule.ancestors.term
#     491
#     492 # derivedSection.conditionBrowseModule.browseLeaves
#     493 #     derivedSection.conditionBrowseModule.browseLeaves.id
#     494 #     derivedSection.conditionBrowseModule.browseLeaves.name
#     495 #     derivedSection.conditionBrowseModule.browseLeaves.asFound
#     496 #     derivedSection.conditionBrowseModule.browseLeaves.relevance
#     497
#     498 # derivedSection.conditionBrowseModule.browseBranches
#     499 #     derivedSection.conditionBrowseModule.browseBranches.abbrev
#     500 #     derivedSection.conditionBrowseModule.browseBranches.name
#     501
#     502 # derivedSection.interventionBrowseModule.meshes
#     503 #     derivedSection.interventionBrowseModule.meshes.id
#     504 #     derivedSection.interventionBrowseModule.meshes.term
#     505
#     506 # derivedSection.interventionBrowseModule.ancestors
#     507 #     derivedSection.interventionBrowseModule.ancestors.id
#     508 #     derivedSection.interventionBrowseModule.ancestors.term
#     509
#     510 # derivedSection.interventionBrowseModule.browseLeaves
#     511 #     derivedSection.interventionBrowseModule.browseLeaves.id
#     512 #     derivedSection.interventionBrowseModule.browseLeaves.name
#     513 #     derivedSection.interventionBrowseModule.browseLeaves.asFound
#     514 #     derivedSection.interventionBrowseModule.browseLeaves.relevance
#     515
#     516 # derivedSection.interventionBrowseModule.browseBranches
#     517 #     derivedSection.interventionBrowseModule.browseBranches.abbrev
#     518 #     derivedSection.interventionBrowseModule.browseBranches.name
#     519
#     520
#     521 })
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'protocolSection.oversightModule.isPpsd'

# %%
# print(study_df.head(6))

# %%
study_df.head(20).to_csv("sample.csv", index=False)

# %%
transposed = (study_df.transpose())

# %%
print(pd.to_datetime('2025-06'))
# Out:
# 2025-06-01 00:00:00
